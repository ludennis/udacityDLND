# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:13, 235KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:100])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
vocab_to_int
# Out:
# {'the': 0,
#  'of': 1,
#  'and': 2,
#  'one': 3,
#  'in': 4,
#  'a': 5,
#  'to': 6,
#  'zero': 7,
#  'nine': 8,
#  'two': 9,
#  'is': 10,
#  'as': 11,
#  'eight': 12,
#  'for': 13,
#  's': 14,
#  'five': 15,
#  'three': 16,
#  'was': 17,
#  'by': 18,
#  'that': 19,
#  'four': 20,
#  'six': 21,
#  'seven': 22,
#  'with': 23,
#  'on': 24,
#  'are': 25,
#  'it': 26,
#  'from': 27,
#  'or': 28,
#  'his': 29,
#  'an': 30,
#  'be': 31,
#  'this': 32,
#  'which': 33,
#  'at': 34,
#  'he': 35,
#  'also': 36,
#  'not': 37,
#  'have': 38,
#  'were': 39,
#  'has': 40,
#  'but': 41,
#  'other': 42,
#  'their': 43,
#  'its': 44,
#  'first': 45,
#  'they': 46,
#  'some': 47,
#  'had': 48,
#  'all': 49,
#  'more': 50,
#  'most': 51,
#  'can': 52,
#  'been': 53,
#  'such': 54,
#  'many': 55,
#  'who': 56,
#  'new': 57,
#  'used': 58,
#  'there': 59,
#  'after': 60,
#  'when': 61,
#  'into': 62,
#  'american': 63,
#  'time': 64,
#  'these': 65,
#  'only': 66,
#  'see': 67,
#  'may': 68,
#  'than': 69,
#  'world': 70,
#  'i': 71,
#  'b': 72,
#  'would': 73,
#  'd': 74,
#  'no': 75,
#  'however': 76,
#  'between': 77,
#  'about': 78,
#  'over': 79,
#  'years': 80,
#  'states': 81,
#  'people': 82,
#  'war': 83,
#  'during': 84,
#  'united': 85,
#  'known': 86,
#  'if': 87,
#  'called': 88,
#  'use': 89,
#  'th': 90,
#  'system': 91,
#  'often': 92,
#  'state': 93,
#  'so': 94,
#  'history': 95,
#  'will': 96,
#  'up': 97,
#  'while': 98,
#  'where': 99,
#  'city': 100,
#  'being': 101,
#  'english': 102,
#  'then': 103,
#  'any': 104,
#  'both': 105,
#  'under': 106,
#  'out': 107,
#  'made': 108,
#  'well': 109,
#  'her': 110,
#  'e': 111,
#  'number': 112,
#  'government': 113,
#  'them': 114,
#  'm': 115,
#  'later': 116,
#  'since': 117,
#  'him': 118,
#  'part': 119,
#  'name': 120,
#  'c': 121,
#  'century': 122,
#  'through': 123,
#  'because': 124,
#  'x': 125,
#  'university': 126,
#  'early': 127,
#  'life': 128,
#  'british': 129,
#  'year': 130,
#  'like': 131,
#  'same': 132,
#  'including': 133,
#  'became': 134,
#  'example': 135,
#  'day': 136,
#  'each': 137,
#  'even': 138,
#  'work': 139,
#  'language': 140,
#  'although': 141,
#  'several': 142,
#  'form': 143,
#  'john': 144,
#  'u': 145,
#  'national': 146,
#  'very': 147,
#  'much': 148,
#  'g': 149,
#  'french': 150,
#  'before': 151,
#  'general': 152,
#  'what': 153,
#  't': 154,
#  'against': 155,
#  'n': 156,
#  'high': 157,
#  'links': 158,
#  'could': 159,
#  'based': 160,
#  'those': 161,
#  'now': 162,
#  'second': 163,
#  'de': 164,
#  'music': 165,
#  'another': 166,
#  'large': 167,
#  'she': 168,
#  'f': 169,
#  'external': 170,
#  'german': 171,
#  'different': 172,
#  'modern': 173,
#  'great': 174,
#  'do': 175,
#  'common': 176,
#  'set': 177,
#  'list': 178,
#  'south': 179,
#  'series': 180,
#  'major': 181,
#  'game': 182,
#  'power': 183,
#  'long': 184,
#  'country': 185,
#  'king': 186,
#  'law': 187,
#  'group': 188,
#  'film': 189,
#  'still': 190,
#  'until': 191,
#  'north': 192,
#  'international': 193,
#  'term': 194,
#  'we': 195,
#  'end': 196,
#  'book': 197,
#  'found': 198,
#  'own': 199,
#  'political': 200,
#  'party': 201,
#  'order': 202,
#  'usually': 203,
#  'president': 204,
#  'church': 205,
#  'you': 206,
#  'death': 207,
#  'theory': 208,
#  'area': 209,
#  'around': 210,
#  'include': 211,
#  'god': 212,
#  'ii': 213,
#  'way': 214,
#  'did': 215,
#  'military': 216,
#  'population': 217,
#  'using': 218,
#  'though': 219,
#  'small': 220,
#  'following': 221,
#  'within': 222,
#  'non': 223,
#  'human': 224,
#  'left': 225,
#  'main': 226,
#  'among': 227,
#  'point': 228,
#  'r': 229,
#  'due': 230,
#  'p': 231,
#  'considered': 232,
#  'public': 233,
#  'popular': 234,
#  'computer': 235,
#  'west': 236,
#  'family': 237,
#  'east': 238,
#  'information': 239,
#  'important': 240,
#  'european': 241,
#  'man': 242,
#  'sometimes': 243,
#  'right': 244,
#  'old': 245,
#  'free': 246,
#  'word': 247,
#  'without': 248,
#  'last': 249,
#  'us': 250,
#  'members': 251,
#  'given': 252,
#  'times': 253,
#  'roman': 254,
#  'make': 255,
#  'h': 256,
#  'age': 257,
#  'place': 258,
#  'l': 259,
#  'thus': 260,
#  'science': 261,
#  'case': 262,
#  'become': 263,
#  'systems': 264,
#  'union': 265,
#  'born': 266,
#  'york': 267,
#  'line': 268,
#  'countries': 269,
#  'does': 270,
#  'isbn': 271,
#  'st': 272,
#  'control': 273,
#  'various': 274,
#  'others': 275,
#  'house': 276,
#  'article': 277,
#  'island': 278,
#  'should': 279,
#  'led': 280,
#  'back': 281,
#  'period': 282,
#  'player': 283,
#  'europe': 284,
#  'languages': 285,
#  'central': 286,
#  'water': 287,
#  'few': 288,
#  'western': 289,
#  'home': 290,
#  'began': 291,
#  'generally': 292,
#  'less': 293,
#  'k': 294,
#  'similar': 295,
#  'written': 296,
#  'original': 297,
#  'best': 298,
#  'must': 299,
#  'according': 300,
#  'school': 301,
#  'france': 302,
#  'air': 303,
#  'single': 304,
#  'force': 305,
#  'v': 306,
#  'land': 307,
#  'groups': 308,
#  'down': 309,
#  'how': 310,
#  'works': 311,
#  'development': 312,
#  'official': 313,
#  'support': 314,
#  'england': 315,
#  'j': 316,
#  'rather': 317,
#  'data': 318,
#  'space': 319,
#  'greek': 320,
#  'km': 321,
#  'named': 322,
#  'germany': 323,
#  'just': 324,
#  'games': 325,
#  'said': 326,
#  'version': 327,
#  'late': 328,
#  'earth': 329,
#  'company': 330,
#  'every': 331,
#  'economic': 332,
#  'short': 333,
#  'published': 334,
#  'black': 335,
#  'army': 336,
#  'off': 337,
#  'london': 338,
#  'million': 339,
#  'body': 340,
#  'field': 341,
#  'christian': 342,
#  'either': 343,
#  'social': 344,
#  'empire': 345,
#  'o': 346,
#  'developed': 347,
#  'standard': 348,
#  'court': 349,
#  'service': 350,
#  'kingdom': 351,
#  'along': 352,
#  'college': 353,
#  'republic': 354,
#  'sea': 355,
#  'america': 356,
#  'today': 357,
#  'result': 358,
#  'held': 359,
#  'team': 360,
#  'light': 361,
#  'means': 362,
#  'never': 363,
#  'especially': 364,
#  'third': 365,
#  'further': 366,
#  'character': 367,
#  'forces': 368,
#  'take': 369,
#  'men': 370,
#  'society': 371,
#  'show': 372,
#  'open': 373,
#  'possible': 374,
#  'fact': 375,
#  'battle': 376,
#  'took': 377,
#  'former': 378,
#  'books': 379,
#  'soviet': 380,
#  'river': 381,
#  'children': 382,
#  'having': 383,
#  'good': 384,
#  'local': 385,
#  'current': 386,
#  'son': 387,
#  'process': 388,
#  'natural': 389,
#  'present': 390,
#  'himself': 391,
#  'islands': 392,
#  'total': 393,
#  'near': 394,
#  'white': 395,
#  'days': 396,
#  'person': 397,
#  'itself': 398,
#  'seen': 399,
#  'culture': 400,
#  'little': 401,
#  'above': 402,
#  'software': 403,
#  'largest': 404,
#  'words': 405,
#  'upon': 406,
#  'level': 407,
#  'father': 408,
#  'created': 409,
#  'side': 410,
#  'red': 411,
#  'references': 412,
#  'press': 413,
#  'full': 414,
#  'region': 415,
#  'almost': 416,
#  'image': 417,
#  'al': 418,
#  'famous': 419,
#  'play': 420,
#  'came': 421,
#  'role': 422,
#  'once': 423,
#  'certain': 424,
#  'league': 425,
#  'jewish': 426,
#  'james': 427,
#  'january': 428,
#  'site': 429,
#  'again': 430,
#  'numbers': 431,
#  'art': 432,
#  'member': 433,
#  'areas': 434,
#  'movement': 435,
#  'religious': 436,
#  'type': 437,
#  'march': 438,
#  'community': 439,
#  'story': 440,
#  'played': 441,
#  'production': 442,
#  'released': 443,
#  'center': 444,
#  'rights': 445,
#  'real': 446,
#  'related': 447,
#  'foreign': 448,
#  'low': 449,
#  'ancient': 450,
#  'terms': 451,
#  'view': 452,
#  'source': 453,
#  'act': 454,
#  'minister': 455,
#  'change': 456,
#  'energy': 457,
#  'produced': 458,
#  'research': 459,
#  'actor': 460,
#  'making': 461,
#  'civil': 462,
#  'december': 463,
#  'women': 464,
#  'special': 465,
#  'style': 466,
#  'william': 467,
#  'design': 468,
#  'japanese': 469,
#  'available': 470,
#  'chinese': 471,
#  'forms': 472,
#  'canada': 473,
#  'northern': 474,
#  'died': 475,
#  'class': 476,
#  'living': 477,
#  'next': 478,
#  'particular': 479,
#  'program': 480,
#  'council': 481,
#  'television': 482,
#  'head': 483,
#  'david': 484,
#  'china': 485,
#  'middle': 486,
#  'established': 487,
#  'hand': 488,
#  'bc': 489,
#  'far': 490,
#  'july': 491,
#  'function': 492,
#  'position': 493,
#  'y': 494,
#  'built': 495,
#  'george': 496,
#  'band': 497,
#  'together': 498,
#  'w': 499,
#  'latin': 500,
#  'thought': 501,
#  'eastern': 502,
#  'charles': 503,
#  'parts': 504,
#  'instead': 505,
#  'study': 506,
#  'might': 507,
#  'india': 508,
#  'code': 509,
#  'included': 510,
#  'meaning': 511,
#  'trade': 512,
#  'per': 513,
#  'june': 514,
#  'least': 515,
#  'half': 516,
#  'model': 517,
#  'economy': 518,
#  'prime': 519,
#  'traditional': 520,
#  'always': 521,
#  'capital': 522,
#  'range': 523,
#  'november': 524,
#  'emperor': 525,
#  'young': 526,
#  'anti': 527,
#  'final': 528,
#  'text': 529,
#  'players': 530,
#  'uk': 531,
#  'april': 532,
#  'run': 533,
#  'september': 534,
#  'addition': 535,
#  'radio': 536,
#  'live': 537,
#  'august': 538,
#  'taken': 539,
#  'note': 540,
#  'italian': 541,
#  'lost': 542,
#  'nature': 543,
#  'project': 544,
#  'technology': 545,
#  'spanish': 546,
#  'october': 547,
#  'recent': 548,
#  'rate': 549,
#  'won': 550,
#  'true': 551,
#  'value': 552,
#  'uses': 553,
#  'russian': 554,
#  'est': 555,
#  'wrote': 556,
#  'effect': 557,
#  'album': 558,
#  'southern': 559,
#  'africa': 560,
#  'whose': 561,
#  'top': 562,
#  'historical': 563,
#  'australia': 564,
#  'catholic': 565,
#  'particularly': 566,
#  'self': 567,
#  'structure': 568,
#  'record': 569,
#  'evidence': 570,
#  'rule': 571,
#  'themselves': 572,
#  'influence': 573,
#  'cases': 574,
#  'subject': 575,
#  'referred': 576,
#  'continued': 577,
#  'nations': 578,
#  'below': 579,
#  'rock': 580,
#  'japan': 581,
#  'com': 582,
#  'song': 583,
#  'throughout': 584,
#  'names': 585,
#  'female': 586,
#  'title': 587,
#  'therefore': 588,
#  'our': 589,
#  'office': 590,
#  'star': 591,
#  'paul': 592,
#  'too': 593,
#  'cities': 594,
#  'february': 595,
#  'independent': 596,
#  'author': 597,
#  'problem': 598,
#  'species': 599,
#  'education': 600,
#  'done': 601,
#  'philosophy': 602,
#  'come': 603,
#  'higher': 604,
#  'originally': 605,
#  'market': 606,
#  'town': 607,
#  'my': 608,
#  'season': 609,
#  'love': 610,
#  'strong': 611,
#  'israel': 612,
#  'irish': 613,
#  'writer': 614,
#  'films': 615,
#  'elements': 616,
#  'robert': 617,
#  'whether': 618,
#  'despite': 619,
#  'eventually': 620,
#  'here': 621,
#  'football': 622,
#  'action': 623,
#  'internet': 624,
#  'individual': 625,
#  'sound': 626,
#  'network': 627,
#  'described': 628,
#  'practice': 629,
#  'characters': 630,
#  're': 631,
#  'royal': 632,
#  'la': 633,
#  'events': 634,
#  'formed': 635,
#  'commonly': 636,
#  'base': 637,
#  'received': 638,
#  'african': 639,
#  'problems': 640,
#  'food': 641,
#  'jews': 642,
#  'able': 643,
#  'male': 644,
#  'typically': 645,
#  'mass': 646,
#  'complex': 647,
#  'lower': 648,
#  'includes': 649,
#  'outside': 650,
#  'legal': 651,
#  'complete': 652,
#  'significant': 653,
#  'parliament': 654,
#  'actually': 655,
#  'business': 656,
#  'fiction': 657,
#  'physical': 658,
#  'followed': 659,
#  'deaths': 660,
#  'key': 661,
#  'leader': 662,
#  'widely': 663,
#  'page': 664,
#  'basic': 665,
#  'types': 666,
#  'henry': 667,
#  'elected': 668,
#  'beginning': 669,
#  'fire': 670,
#  'building': 671,
#  'independence': 672,
#  'went': 673,
#  'movie': 674,
#  'aircraft': 675,
#  'ever': 676,
#  'canadian': 677,
#  'material': 678,
#  'births': 679,
#  'video': 680,
#  'news': 681,
#  'future': 682,
#  'scientific': 683,
#  'simply': 684,
#  'go': 685,
#  'defined': 686,
#  'laws': 687,
#  'get': 688,
#  'close': 689,
#  'industry': 690,
#  'specific': 691,
#  'examples': 692,
#  'believe': 693,
#  'services': 694,
#  'idea': 695,
#  'method': 696,
#  'introduced': 697,
#  'points': 698,
#  'return': 699,
#  'cause': 700,
#  'indian': 701,
#  'britain': 702,
#  'features': 703,
#  'majority': 704,
#  'size': 705,
#  'post': 706,
#  'lead': 707,
#  'organization': 708,
#  'cannot': 709,
#  'designed': 710,
#  'ireland': 711,
#  'cross': 712,
#  'classical': 713,
#  'personal': 714,
#  'writing': 715,
#  'concept': 716,
#  'associated': 717,
#  'required': 718,
#  'soon': 719,
#  'changes': 720,
#  'california': 721,
#  'located': 722,
#  'sense': 723,
#  'believed': 724,
#  'away': 725,
#  'started': 726,
#  'co': 727,
#  'religion': 728,
#  'mother': 729,
#  'county': 730,
#  'rules': 731,
#  'studies': 732,
#  'yet': 733,
#  'find': 734,
#  'knowledge': 735,
#  'put': 736,
#  'founded': 737,
#  'policy': 738,
#  'currently': 739,
#  'provide': 740,
#  'working': 741,
#  'media': 742,
#  'election': 743,
#  'australian': 744,
#  'me': 745,
#  'thomas': 746,
#  'allowed': 747,
#  'russia': 748,
#  'earlier': 749,
#  'greater': 750,
#  'limited': 751,
#  'object': 752,
#  'brought': 753,
#  'online': 754,
#  'association': 755,
#  'lord': 756,
#  'mostly': 757,
#  'blue': 758,
#  'constitution': 759,
#  'across': 760,
#  'added': 761,
#  'interest': 762,
#  'things': 763,
#  'relations': 764,
#  'speed': 765,
#  'federal': 766,
#  'singer': 767,
#  'effects': 768,
#  'growth': 769,
#  'sources': 770,
#  'your': 771,
#  'remains': 772,
#  'z': 773,
#  'probably': 774,
#  'gave': 775,
#  'simple': 776,
#  'attack': 777,
#  'longer': 778,
#  'reference': 779,
#  'saint': 780,
#  'success': 781,
#  'killed': 782,
#  'past': 783,
#  'career': 784,
#  'need': 785,
#  'park': 786,
#  'definition': 787,
#  'say': 788,
#  'etc': 789,
#  'give': 790,
#  'peace': 791,
#  'chief': 792,
#  'stories': 793,
#  'security': 794,
#  'wide': 795,
#  'ball': 796,
#  'saw': 797,
#  'machine': 798,
#  'better': 799,
#  'cell': 800,
#  'leading': 801,
#  'becomes': 802,
#  'spain': 803,
#  'larger': 804,
#  'products': 805,
#  'parties': 806,
#  'night': 807,
#  'remained': 808,
#  'prize': 809,
#  'months': 810,
#  'website': 811,
#  'big': 812,
#  'cultural': 813,
#  'money': 814,
#  'help': 815,
#  'territory': 816,
#  'private': 817,
#  'moved': 818,
#  'letter': 819,
#  'wife': 820,
#  'politics': 821,
#  'lines': 822,
#  'largely': 823,
#  'contains': 824,
#  'companies': 825,
#  'lake': 826,
#  'perhaps': 827,
#  'green': 828,
#  'already': 829,
#  'dead': 830,
#  'iii': 831,
#  'library': 832,
#  'separate': 833,
#  'refer': 834,
#  'makes': 835,
#  'appeared': 836,
#  'dutch': 837,
#  'holy': 838,
#  'era': 839,
#  'novel': 840,
#  'successful': 841,
#  'italy': 842,
#  'letters': 843,
#  'results': 844,
#  'matter': 845,
#  'produce': 846,
#  'origin': 847,
#  'claim': 848,
#  'whole': 849,
#  'directly': 850,
#  'attempt': 851,
#  'actress': 852,
#  'surface': 853,
#  'revolution': 854,
#  'highly': 855,
#  'caused': 856,
#  'status': 857,
#  'musical': 858,
#  'richard': 859,
#  'commercial': 860,
#  'division': 861,
#  'color': 862,
#  'health': 863,
#  'coast': 864,
#  'release': 865,
#  'latter': 866,
#  'authority': 867,
#  'treaty': 868,
#  'turn': 869,
#  'michael': 870,
#  'nation': 871,
#  'direct': 872,
#  'asia': 873,
#  'edition': 874,
#  'programming': 875,
#  'playing': 876,
#  'date': 877,
#  'mary': 878,
#  'native': 879,
#  'whom': 880,
#  'married': 881,
#  'towards': 882,
#  'issues': 883,
#  'double': 884,
#  'primary': 885,
#  'basis': 886,
#  'allow': 887,
#  'enough': 888,
#  'memory': 889,
#  'reason': 890,
#  'web': 891,
#  'exist': 892,
#  'provided': 893,
#  'oil': 894,
#  'course': 895,
#  'functions': 896,
#  'alexander': 897,
#  'analysis': 898,
#  'chemical': 899,
#  'mid': 900,
#  'replaced': 901,
#  'queen': 902,
#  'claims': 903,
#  'tv': 904,
#  'sun': 905,
#  'literature': 906,
#  'metal': 907,
#  'amount': 908,
#  'divided': 909,
#  'blood': 910,
#  'likely': 911,
#  'access': 912,
#  'average': 913,
#  'length': 914,
#  'smaller': 915,
#  'medical': 916,
#  'property': 917,
#  'students': 918,
#  'degree': 919,
#  'elections': 920,
#  'club': 921,
#  'claimed': 922,
#  'performance': 923,
#  'director': 924,
#  'digital': 925,
#  'front': 926,
#  'museum': 927,
#  'difficult': 928,
#  'tradition': 929,
#  'nearly': 930,
#  'schools': 931,
#  'washington': 932,
#  'gas': 933,
#  'jesus': 934,
#  'map': 935,
#  'louis': 936,
#  'rome': 937,
#  'unit': 938,
#  'baseball': 939,
#  'mind': 940,
#  'peter': 941,
#  'mark': 942,
#  'collection': 943,
#  'product': 944,
#  'congress': 945,
#  'programs': 946,
#  'changed': 947,
#  'ideas': 948,
#  'moon': 949,
#  'entire': 950,
#  'user': 951,
#  'ground': 952,
#  'records': 953,
#  'frequently': 954,
#  'increase': 955,
#  'highest': 956,
#  'sent': 957,
#  'finally': 958,
#  'board': 959,
#  'don': 960,
#  'notable': 961,
#  'read': 962,
#  'methods': 963,
#  'recently': 964,
#  'bit': 965,
#  'involved': 966,
#  'variety': 967,
#  'call': 968,
#  'democratic': 969,
#  'ten': 970,
#  'served': 971,
#  'minor': 972,
#  'hard': 973,
#  'birth': 974,
#  'objects': 975,
#  'nuclear': 976,
#  'increased': 977,
#  'section': 978,
#  'street': 979,
#  'windows': 980,
#  'relatively': 981,
#  'car': 982,
#  'move': 983,
#  'create': 984,
#  'returned': 985,
#  'bank': 986,
#  'conditions': 987,
#  'operation': 988,
#  'adopted': 989,
#  'relationship': 990,
#  'christ': 991,
#  'hall': 992,
#  'appear': 993,
#  'rest': 994,
#  'child': 995,
#  'element': 996,
#  'appears': 997,
#  'takes': 998,
#  'fall': 999,
#  ...}

# %%
int_to_vocab
# Out:
# {0: 'the',
#  1: 'of',
#  2: 'and',
#  3: 'one',
#  4: 'in',
#  5: 'a',
#  6: 'to',
#  7: 'zero',
#  8: 'nine',
#  9: 'two',
#  10: 'is',
#  11: 'as',
#  12: 'eight',
#  13: 'for',
#  14: 's',
#  15: 'five',
#  16: 'three',
#  17: 'was',
#  18: 'by',
#  19: 'that',
#  20: 'four',
#  21: 'six',
#  22: 'seven',
#  23: 'with',
#  24: 'on',
#  25: 'are',
#  26: 'it',
#  27: 'from',
#  28: 'or',
#  29: 'his',
#  30: 'an',
#  31: 'be',
#  32: 'this',
#  33: 'which',
#  34: 'at',
#  35: 'he',
#  36: 'also',
#  37: 'not',
#  38: 'have',
#  39: 'were',
#  40: 'has',
#  41: 'but',
#  42: 'other',
#  43: 'their',
#  44: 'its',
#  45: 'first',
#  46: 'they',
#  47: 'some',
#  48: 'had',
#  49: 'all',
#  50: 'more',
#  51: 'most',
#  52: 'can',
#  53: 'been',
#  54: 'such',
#  55: 'many',
#  56: 'who',
#  57: 'new',
#  58: 'used',
#  59: 'there',
#  60: 'after',
#  61: 'when',
#  62: 'into',
#  63: 'american',
#  64: 'time',
#  65: 'these',
#  66: 'only',
#  67: 'see',
#  68: 'may',
#  69: 'than',
#  70: 'world',
#  71: 'i',
#  72: 'b',
#  73: 'would',
#  74: 'd',
#  75: 'no',
#  76: 'however',
#  77: 'between',
#  78: 'about',
#  79: 'over',
#  80: 'years',
#  81: 'states',
#  82: 'people',
#  83: 'war',
#  84: 'during',
#  85: 'united',
#  86: 'known',
#  87: 'if',
#  88: 'called',
#  89: 'use',
#  90: 'th',
#  91: 'system',
#  92: 'often',
#  93: 'state',
#  94: 'so',
#  95: 'history',
#  96: 'will',
#  97: 'up',
#  98: 'while',
#  99: 'where',
#  100: 'city',
#  101: 'being',
#  102: 'english',
#  103: 'then',
#  104: 'any',
#  105: 'both',
#  106: 'under',
#  107: 'out',
#  108: 'made',
#  109: 'well',
#  110: 'her',
#  111: 'e',
#  112: 'number',
#  113: 'government',
#  114: 'them',
#  115: 'm',
#  116: 'later',
#  117: 'since',
#  118: 'him',
#  119: 'part',
#  120: 'name',
#  121: 'c',
#  122: 'century',
#  123: 'through',
#  124: 'because',
#  125: 'x',
#  126: 'university',
#  127: 'early',
#  128: 'life',
#  129: 'british',
#  130: 'year',
#  131: 'like',
#  132: 'same',
#  133: 'including',
#  134: 'became',
#  135: 'example',
#  136: 'day',
#  137: 'each',
#  138: 'even',
#  139: 'work',
#  140: 'language',
#  141: 'although',
#  142: 'several',
#  143: 'form',
#  144: 'john',
#  145: 'u',
#  146: 'national',
#  147: 'very',
#  148: 'much',
#  149: 'g',
#  150: 'french',
#  151: 'before',
#  152: 'general',
#  153: 'what',
#  154: 't',
#  155: 'against',
#  156: 'n',
#  157: 'high',
#  158: 'links',
#  159: 'could',
#  160: 'based',
#  161: 'those',
#  162: 'now',
#  163: 'second',
#  164: 'de',
#  165: 'music',
#  166: 'another',
#  167: 'large',
#  168: 'she',
#  169: 'f',
#  170: 'external',
#  171: 'german',
#  172: 'different',
#  173: 'modern',
#  174: 'great',
#  175: 'do',
#  176: 'common',
#  177: 'set',
#  178: 'list',
#  179: 'south',
#  180: 'series',
#  181: 'major',
#  182: 'game',
#  183: 'power',
#  184: 'long',
#  185: 'country',
#  186: 'king',
#  187: 'law',
#  188: 'group',
#  189: 'film',
#  190: 'still',
#  191: 'until',
#  192: 'north',
#  193: 'international',
#  194: 'term',
#  195: 'we',
#  196: 'end',
#  197: 'book',
#  198: 'found',
#  199: 'own',
#  200: 'political',
#  201: 'party',
#  202: 'order',
#  203: 'usually',
#  204: 'president',
#  205: 'church',
#  206: 'you',
#  207: 'death',
#  208: 'theory',
#  209: 'area',
#  210: 'around',
#  211: 'include',
#  212: 'god',
#  213: 'ii',
#  214: 'way',
#  215: 'did',
#  216: 'military',
#  217: 'population',
#  218: 'using',
#  219: 'though',
#  220: 'small',
#  221: 'following',
#  222: 'within',
#  223: 'non',
#  224: 'human',
#  225: 'left',
#  226: 'main',
#  227: 'among',
#  228: 'point',
#  229: 'r',
#  230: 'due',
#  231: 'p',
#  232: 'considered',
#  233: 'public',
#  234: 'popular',
#  235: 'computer',
#  236: 'west',
#  237: 'family',
#  238: 'east',
#  239: 'information',
#  240: 'important',
#  241: 'european',
#  242: 'man',
#  243: 'sometimes',
#  244: 'right',
#  245: 'old',
#  246: 'free',
#  247: 'word',
#  248: 'without',
#  249: 'last',
#  250: 'us',
#  251: 'members',
#  252: 'given',
#  253: 'times',
#  254: 'roman',
#  255: 'make',
#  256: 'h',
#  257: 'age',
#  258: 'place',
#  259: 'l',
#  260: 'thus',
#  261: 'science',
#  262: 'case',
#  263: 'become',
#  264: 'systems',
#  265: 'union',
#  266: 'born',
#  267: 'york',
#  268: 'line',
#  269: 'countries',
#  270: 'does',
#  271: 'isbn',
#  272: 'st',
#  273: 'control',
#  274: 'various',
#  275: 'others',
#  276: 'house',
#  277: 'article',
#  278: 'island',
#  279: 'should',
#  280: 'led',
#  281: 'back',
#  282: 'period',
#  283: 'player',
#  284: 'europe',
#  285: 'languages',
#  286: 'central',
#  287: 'water',
#  288: 'few',
#  289: 'western',
#  290: 'home',
#  291: 'began',
#  292: 'generally',
#  293: 'less',
#  294: 'k',
#  295: 'similar',
#  296: 'written',
#  297: 'original',
#  298: 'best',
#  299: 'must',
#  300: 'according',
#  301: 'school',
#  302: 'france',
#  303: 'air',
#  304: 'single',
#  305: 'force',
#  306: 'v',
#  307: 'land',
#  308: 'groups',
#  309: 'down',
#  310: 'how',
#  311: 'works',
#  312: 'development',
#  313: 'official',
#  314: 'support',
#  315: 'england',
#  316: 'j',
#  317: 'rather',
#  318: 'data',
#  319: 'space',
#  320: 'greek',
#  321: 'km',
#  322: 'named',
#  323: 'germany',
#  324: 'just',
#  325: 'games',
#  326: 'said',
#  327: 'version',
#  328: 'late',
#  329: 'earth',
#  330: 'company',
#  331: 'every',
#  332: 'economic',
#  333: 'short',
#  334: 'published',
#  335: 'black',
#  336: 'army',
#  337: 'off',
#  338: 'london',
#  339: 'million',
#  340: 'body',
#  341: 'field',
#  342: 'christian',
#  343: 'either',
#  344: 'social',
#  345: 'empire',
#  346: 'o',
#  347: 'developed',
#  348: 'standard',
#  349: 'court',
#  350: 'service',
#  351: 'kingdom',
#  352: 'along',
#  353: 'college',
#  354: 'republic',
#  355: 'sea',
#  356: 'america',
#  357: 'today',
#  358: 'result',
#  359: 'held',
#  360: 'team',
#  361: 'light',
#  362: 'means',
#  363: 'never',
#  364: 'especially',
#  365: 'third',
#  366: 'further',
#  367: 'character',
#  368: 'forces',
#  369: 'take',
#  370: 'men',
#  371: 'society',
#  372: 'show',
#  373: 'open',
#  374: 'possible',
#  375: 'fact',
#  376: 'battle',
#  377: 'took',
#  378: 'former',
#  379: 'books',
#  380: 'soviet',
#  381: 'river',
#  382: 'children',
#  383: 'having',
#  384: 'good',
#  385: 'local',
#  386: 'current',
#  387: 'son',
#  388: 'process',
#  389: 'natural',
#  390: 'present',
#  391: 'himself',
#  392: 'islands',
#  393: 'total',
#  394: 'near',
#  395: 'white',
#  396: 'days',
#  397: 'person',
#  398: 'itself',
#  399: 'seen',
#  400: 'culture',
#  401: 'little',
#  402: 'above',
#  403: 'software',
#  404: 'largest',
#  405: 'words',
#  406: 'upon',
#  407: 'level',
#  408: 'father',
#  409: 'created',
#  410: 'side',
#  411: 'red',
#  412: 'references',
#  413: 'press',
#  414: 'full',
#  415: 'region',
#  416: 'almost',
#  417: 'image',
#  418: 'al',
#  419: 'famous',
#  420: 'play',
#  421: 'came',
#  422: 'role',
#  423: 'once',
#  424: 'certain',
#  425: 'league',
#  426: 'jewish',
#  427: 'james',
#  428: 'january',
#  429: 'site',
#  430: 'again',
#  431: 'numbers',
#  432: 'art',
#  433: 'member',
#  434: 'areas',
#  435: 'movement',
#  436: 'religious',
#  437: 'type',
#  438: 'march',
#  439: 'community',
#  440: 'story',
#  441: 'played',
#  442: 'production',
#  443: 'released',
#  444: 'center',
#  445: 'rights',
#  446: 'real',
#  447: 'related',
#  448: 'foreign',
#  449: 'low',
#  450: 'ancient',
#  451: 'terms',
#  452: 'view',
#  453: 'source',
#  454: 'act',
#  455: 'minister',
#  456: 'change',
#  457: 'energy',
#  458: 'produced',
#  459: 'research',
#  460: 'actor',
#  461: 'making',
#  462: 'civil',
#  463: 'december',
#  464: 'women',
#  465: 'special',
#  466: 'style',
#  467: 'william',
#  468: 'design',
#  469: 'japanese',
#  470: 'available',
#  471: 'chinese',
#  472: 'forms',
#  473: 'canada',
#  474: 'northern',
#  475: 'died',
#  476: 'class',
#  477: 'living',
#  478: 'next',
#  479: 'particular',
#  480: 'program',
#  481: 'council',
#  482: 'television',
#  483: 'head',
#  484: 'david',
#  485: 'china',
#  486: 'middle',
#  487: 'established',
#  488: 'hand',
#  489: 'bc',
#  490: 'far',
#  491: 'july',
#  492: 'function',
#  493: 'position',
#  494: 'y',
#  495: 'built',
#  496: 'george',
#  497: 'band',
#  498: 'together',
#  499: 'w',
#  500: 'latin',
#  501: 'thought',
#  502: 'eastern',
#  503: 'charles',
#  504: 'parts',
#  505: 'instead',
#  506: 'study',
#  507: 'might',
#  508: 'india',
#  509: 'code',
#  510: 'included',
#  511: 'meaning',
#  512: 'trade',
#  513: 'per',
#  514: 'june',
#  515: 'least',
#  516: 'half',
#  517: 'model',
#  518: 'economy',
#  519: 'prime',
#  520: 'traditional',
#  521: 'always',
#  522: 'capital',
#  523: 'range',
#  524: 'november',
#  525: 'emperor',
#  526: 'young',
#  527: 'anti',
#  528: 'final',
#  529: 'text',
#  530: 'players',
#  531: 'uk',
#  532: 'april',
#  533: 'run',
#  534: 'september',
#  535: 'addition',
#  536: 'radio',
#  537: 'live',
#  538: 'august',
#  539: 'taken',
#  540: 'note',
#  541: 'italian',
#  542: 'lost',
#  543: 'nature',
#  544: 'project',
#  545: 'technology',
#  546: 'spanish',
#  547: 'october',
#  548: 'recent',
#  549: 'rate',
#  550: 'won',
#  551: 'true',
#  552: 'value',
#  553: 'uses',
#  554: 'russian',
#  555: 'est',
#  556: 'wrote',
#  557: 'effect',
#  558: 'album',
#  559: 'southern',
#  560: 'africa',
#  561: 'whose',
#  562: 'top',
#  563: 'historical',
#  564: 'australia',
#  565: 'catholic',
#  566: 'particularly',
#  567: 'self',
#  568: 'structure',
#  569: 'record',
#  570: 'evidence',
#  571: 'rule',
#  572: 'themselves',
#  573: 'influence',
#  574: 'cases',
#  575: 'subject',
#  576: 'referred',
#  577: 'continued',
#  578: 'nations',
#  579: 'below',
#  580: 'rock',
#  581: 'japan',
#  582: 'com',
#  583: 'song',
#  584: 'throughout',
#  585: 'names',
#  586: 'female',
#  587: 'title',
#  588: 'therefore',
#  589: 'our',
#  590: 'office',
#  591: 'star',
#  592: 'paul',
#  593: 'too',
#  594: 'cities',
#  595: 'february',
#  596: 'independent',
#  597: 'author',
#  598: 'problem',
#  599: 'species',
#  600: 'education',
#  601: 'done',
#  602: 'philosophy',
#  603: 'come',
#  604: 'higher',
#  605: 'originally',
#  606: 'market',
#  607: 'town',
#  608: 'my',
#  609: 'season',
#  610: 'love',
#  611: 'strong',
#  612: 'israel',
#  613: 'irish',
#  614: 'writer',
#  615: 'films',
#  616: 'elements',
#  617: 'robert',
#  618: 'whether',
#  619: 'despite',
#  620: 'eventually',
#  621: 'here',
#  622: 'football',
#  623: 'action',
#  624: 'internet',
#  625: 'individual',
#  626: 'sound',
#  627: 'network',
#  628: 'described',
#  629: 'practice',
#  630: 'characters',
#  631: 're',
#  632: 'royal',
#  633: 'la',
#  634: 'events',
#  635: 'formed',
#  636: 'commonly',
#  637: 'base',
#  638: 'received',
#  639: 'african',
#  640: 'problems',
#  641: 'food',
#  642: 'jews',
#  643: 'able',
#  644: 'male',
#  645: 'typically',
#  646: 'mass',
#  647: 'complex',
#  648: 'lower',
#  649: 'includes',
#  650: 'outside',
#  651: 'legal',
#  652: 'complete',
#  653: 'significant',
#  654: 'parliament',
#  655: 'actually',
#  656: 'business',
#  657: 'fiction',
#  658: 'physical',
#  659: 'followed',
#  660: 'deaths',
#  661: 'key',
#  662: 'leader',
#  663: 'widely',
#  664: 'page',
#  665: 'basic',
#  666: 'types',
#  667: 'henry',
#  668: 'elected',
#  669: 'beginning',
#  670: 'fire',
#  671: 'building',
#  672: 'independence',
#  673: 'went',
#  674: 'movie',
#  675: 'aircraft',
#  676: 'ever',
#  677: 'canadian',
#  678: 'material',
#  679: 'births',
#  680: 'video',
#  681: 'news',
#  682: 'future',
#  683: 'scientific',
#  684: 'simply',
#  685: 'go',
#  686: 'defined',
#  687: 'laws',
#  688: 'get',
#  689: 'close',
#  690: 'industry',
#  691: 'specific',
#  692: 'examples',
#  693: 'believe',
#  694: 'services',
#  695: 'idea',
#  696: 'method',
#  697: 'introduced',
#  698: 'points',
#  699: 'return',
#  700: 'cause',
#  701: 'indian',
#  702: 'britain',
#  703: 'features',
#  704: 'majority',
#  705: 'size',
#  706: 'post',
#  707: 'lead',
#  708: 'organization',
#  709: 'cannot',
#  710: 'designed',
#  711: 'ireland',
#  712: 'cross',
#  713: 'classical',
#  714: 'personal',
#  715: 'writing',
#  716: 'concept',
#  717: 'associated',
#  718: 'required',
#  719: 'soon',
#  720: 'changes',
#  721: 'california',
#  722: 'located',
#  723: 'sense',
#  724: 'believed',
#  725: 'away',
#  726: 'started',
#  727: 'co',
#  728: 'religion',
#  729: 'mother',
#  730: 'county',
#  731: 'rules',
#  732: 'studies',
#  733: 'yet',
#  734: 'find',
#  735: 'knowledge',
#  736: 'put',
#  737: 'founded',
#  738: 'policy',
#  739: 'currently',
#  740: 'provide',
#  741: 'working',
#  742: 'media',
#  743: 'election',
#  744: 'australian',
#  745: 'me',
#  746: 'thomas',
#  747: 'allowed',
#  748: 'russia',
#  749: 'earlier',
#  750: 'greater',
#  751: 'limited',
#  752: 'object',
#  753: 'brought',
#  754: 'online',
#  755: 'association',
#  756: 'lord',
#  757: 'mostly',
#  758: 'blue',
#  759: 'constitution',
#  760: 'across',
#  761: 'added',
#  762: 'interest',
#  763: 'things',
#  764: 'relations',
#  765: 'speed',
#  766: 'federal',
#  767: 'singer',
#  768: 'effects',
#  769: 'growth',
#  770: 'sources',
#  771: 'your',
#  772: 'remains',
#  773: 'z',
#  774: 'probably',
#  775: 'gave',
#  776: 'simple',
#  777: 'attack',
#  778: 'longer',
#  779: 'reference',
#  780: 'saint',
#  781: 'success',
#  782: 'killed',
#  783: 'past',
#  784: 'career',
#  785: 'need',
#  786: 'park',
#  787: 'definition',
#  788: 'say',
#  789: 'etc',
#  790: 'give',
#  791: 'peace',
#  792: 'chief',
#  793: 'stories',
#  794: 'security',
#  795: 'wide',
#  796: 'ball',
#  797: 'saw',
#  798: 'machine',
#  799: 'better',
#  800: 'cell',
#  801: 'leading',
#  802: 'becomes',
#  803: 'spain',
#  804: 'larger',
#  805: 'products',
#  806: 'parties',
#  807: 'night',
#  808: 'remained',
#  809: 'prize',
#  810: 'months',
#  811: 'website',
#  812: 'big',
#  813: 'cultural',
#  814: 'money',
#  815: 'help',
#  816: 'territory',
#  817: 'private',
#  818: 'moved',
#  819: 'letter',
#  820: 'wife',
#  821: 'politics',
#  822: 'lines',
#  823: 'largely',
#  824: 'contains',
#  825: 'companies',
#  826: 'lake',
#  827: 'perhaps',
#  828: 'green',
#  829: 'already',
#  830: 'dead',
#  831: 'iii',
#  832: 'library',
#  833: 'separate',
#  834: 'refer',
#  835: 'makes',
#  836: 'appeared',
#  837: 'dutch',
#  838: 'holy',
#  839: 'era',
#  840: 'novel',
#  841: 'successful',
#  842: 'italy',
#  843: 'letters',
#  844: 'results',
#  845: 'matter',
#  846: 'produce',
#  847: 'origin',
#  848: 'claim',
#  849: 'whole',
#  850: 'directly',
#  851: 'attempt',
#  852: 'actress',
#  853: 'surface',
#  854: 'revolution',
#  855: 'highly',
#  856: 'caused',
#  857: 'status',
#  858: 'musical',
#  859: 'richard',
#  860: 'commercial',
#  861: 'division',
#  862: 'color',
#  863: 'health',
#  864: 'coast',
#  865: 'release',
#  866: 'latter',
#  867: 'authority',
#  868: 'treaty',
#  869: 'turn',
#  870: 'michael',
#  871: 'nation',
#  872: 'direct',
#  873: 'asia',
#  874: 'edition',
#  875: 'programming',
#  876: 'playing',
#  877: 'date',
#  878: 'mary',
#  879: 'native',
#  880: 'whom',
#  881: 'married',
#  882: 'towards',
#  883: 'issues',
#  884: 'double',
#  885: 'primary',
#  886: 'basis',
#  887: 'allow',
#  888: 'enough',
#  889: 'memory',
#  890: 'reason',
#  891: 'web',
#  892: 'exist',
#  893: 'provided',
#  894: 'oil',
#  895: 'course',
#  896: 'functions',
#  897: 'alexander',
#  898: 'analysis',
#  899: 'chemical',
#  900: 'mid',
#  901: 'replaced',
#  902: 'queen',
#  903: 'claims',
#  904: 'tv',
#  905: 'sun',
#  906: 'literature',
#  907: 'metal',
#  908: 'amount',
#  909: 'divided',
#  910: 'blood',
#  911: 'likely',
#  912: 'access',
#  913: 'average',
#  914: 'length',
#  915: 'smaller',
#  916: 'medical',
#  917: 'property',
#  918: 'students',
#  919: 'degree',
#  920: 'elections',
#  921: 'club',
#  922: 'claimed',
#  923: 'performance',
#  924: 'director',
#  925: 'digital',
#  926: 'front',
#  927: 'museum',
#  928: 'difficult',
#  929: 'tradition',
#  930: 'nearly',
#  931: 'schools',
#  932: 'washington',
#  933: 'gas',
#  934: 'jesus',
#  935: 'map',
#  936: 'louis',
#  937: 'rome',
#  938: 'unit',
#  939: 'baseball',
#  940: 'mind',
#  941: 'peter',
#  942: 'mark',
#  943: 'collection',
#  944: 'product',
#  945: 'congress',
#  946: 'programs',
#  947: 'changed',
#  948: 'ideas',
#  949: 'moon',
#  950: 'entire',
#  951: 'user',
#  952: 'ground',
#  953: 'records',
#  954: 'frequently',
#  955: 'increase',
#  956: 'highest',
#  957: 'sent',
#  958: 'finally',
#  959: 'board',
#  960: 'don',
#  961: 'notable',
#  962: 'read',
#  963: 'methods',
#  964: 'recently',
#  965: 'bit',
#  966: 'involved',
#  967: 'variety',
#  968: 'call',
#  969: 'democratic',
#  970: 'ten',
#  971: 'served',
#  972: 'minor',
#  973: 'hard',
#  974: 'birth',
#  975: 'objects',
#  976: 'nuclear',
#  977: 'increased',
#  978: 'section',
#  979: 'street',
#  980: 'windows',
#  981: 'relatively',
#  982: 'car',
#  983: 'move',
#  984: 'create',
#  985: 'returned',
#  986: 'bank',
#  987: 'conditions',
#  988: 'operation',
#  989: 'adopted',
#  990: 'relationship',
#  991: 'christ',
#  992: 'hall',
#  993: 'appear',
#  994: 'rest',
#  995: 'child',
#  996: 'element',
#  997: 'appears',
#  998: 'takes',
#  999: 'fall',
#  ...}

# %%
int_words
# Out:
# [5233,
#  3080,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10571,
#  133,
#  0,
#  27349,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15067,
#  58112,
#  1,
#  0,
#  150,
#  854,
#  3580,
#  0,
#  194,
#  10,
#  190,
#  58,
#  4,
#  5,
#  10712,
#  214,
#  6,
#  1324,
#  104,
#  454,
#  19,
#  58,
#  2731,
#  362,
#  6,
#  3672,
#  0,
#  708,
#  1,
#  371,
#  26,
#  40,
#  36,
#  53,
#  539,
#  97,
#  11,
#  5,
#  1423,
#  2757,
#  18,
#  567,
#  686,
#  7088,
#  0,
#  247,
#  5233,
#  10,
#  1052,
#  27,
#  0,
#  320,
#  248,
#  44611,
#  2877,
#  792,
#  186,
#  5233,
#  11,
#  5,
#  200,
#  602,
#  10,
#  0,
#  1134,
#  19,
#  2621,
#  25,
#  8983,
#  2,
#  279,
#  31,
#  4147,
#  141,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  153,
#  32,
#  362,
#  5233,
#  36,
#  1137,
#  6,
#  447,
#  344,
#  1818,
#  19,
#  4860,
#  0,
#  6753,
#  1,
#  7573,
#  1774,
#  566,
#  0,
#  93,
#  0,
#  247,
#  11064,
#  11,
#  51,
#  7088,
#  89,
#  26,
#  270,
#  37,
#  5948,
#  4861,
#  20299,
#  28,
#  53721,
#  41,
#  317,
#  5,
#  25636,
#  527,
#  7573,
#  371,
#  4,
#  258,
#  1,
#  153,
#  25,
#  1206,
#  11,
#  7573,
#  200,
#  1576,
#  2,
#  15200,
#  332,
#  1774,
#  7088,
#  4860,
#  344,
#  764,
#  160,
#  406,
#  5690,
#  755,
#  1,
#  4105,
#  1131,
#  4331,
#  1536,
#  2,
#  567,
#  8117,
#  98,
#  5233,
#  10,
#  51,
#  1407,
#  686,
#  18,
#  153,
#  26,
#  10,
#  155,
#  7088,
#  36,
#  2033,
#  1423,
#  8174,
#  1,
#  153,
#  46,
#  693,
#  6,
#  31,
#  5,
#  4148,
#  246,
#  371,
#  76,
#  948,
#  78,
#  310,
#  30,
#  4778,
#  371,
#  507,
#  139,
#  2312,
#  3553,
#  364,
#  23,
#  1821,
#  6,
#  1902,
#  59,
#  10,
#  36,
#  8399,
#  78,
#  310,
#  5,
#  246,
#  371,
#  507,
#  31,
#  753,
#  78,
#  1732,
#  2,
#  8040,
#  24172,
#  2,
#  275,
#  1693,
#  19,
#  151,
#  1032,
#  95,
#  224,
#  371,
#  17,
#  1813,
#  24,
#  4778,
#  1556,
#  51,
#  8118,
#  1465,
#  24172,
#  2,
#  12743,
#  4,
#  6130,
#  19,
#  4187,
#  21148,
#  2427,
#  39,
#  16455,
#  2,
#  7239,
#  861,
#  1,
#  1193,
#  10207,
#  2514,
#  28,
#  15068,
#  187,
#  2,
#  48,
#  1123,
#  912,
#  6,
#  1049,
#  467,
#  12297,
#  7088,
#  133,
#  0,
#  0,
#  11064,
#  3055,
#  2,
#  12060,
#  734,
#  4778,
#  6598,
#  4,
#  14622,
#  27,
#  450,
#  485,
#  24172,
#  198,
#  295,
#  948,
#  4,
#  20027,
#  20300,
#  1,
#  53722,
#  300,
#  6,
#  24172,
#  20300,
#  16456,
#  0,
#  30106,
#  1,
#  0,
#  93,
#  44,
#  3832,
#  2,
#  53723,
#  2,
#  3807,
#  0,
#  3412,
#  1,
#  0,
#  1776,
#  187,
#  1,
#  0,
#  625,
#  0,
#  13141,
#  1,
#  3,
#  21,
#  90,
#  122,
#  284,
#  25,
#  243,
#  232,
#  6,
#  31,
#  436,
#  26184,
#  1,
#  173,
#  5233,
#  7699,
#  2534,
#  4,
#  29,
#  95,
#  1,
#  289,
#  602,
#  4308,
#  19,
#  0,
#  13141,
#  16456,
#  49,
#  187,
#  117,
#  46,
#  359,
#  19,
#  0,
#  384,
#  242,
#  96,
#  31,
#  5234,
#  34,
#  331,
#  2723,
#  18,
#  0,
#  838,
#  1376,
#  27,
#  32,
#  8761,
#  46,
#  6470,
#  34,
#  3243,
#  0,
#  27349,
#  28,
#  551,
#  42432,
#  39,
#  30,
#  127,
#  53724,
#  435,
#  84,
#  0,
#  64,
#  1,
#  0,
#  102,
#  462,
#  83,
#  2,
#  25,
#  232,
#  18,
#  47,
#  11,
#  26184,
#  1,
#  173,
#  5233,
#  4,
#  0,
#  173,
#  839,
#  0,
#  45,
#  6,
#  89,
#  0,
#  194,
#  6,
#  1014,
#  1043,
#  42,
#  69,
#  4861,
#  17,
#  936,
#  14920,
#  4571,
#  164,
#  4,
#  29,
#  40561,
#  11815,
#  22892,
#  259,
#  1225,
#  58113,
#  3,
#  22,
#  7,
#  16,
#  99,
#  35,
#  628,
#  0,
#  2662,
#  63,
#  371,
#  33,
#  48,
#  75,
#  93,
#  687,
#  14777,
#  4044,
#  28,
#  817,
#  917,
#  11,
#  101,
#  4,
#  11064,
#  2534,
#  362,
#  5,
#  6054,
#  2,
#  662,
#  4,
#  0,
#  63,
#  701,
#  435,
#  40,
#  4218,
#  1289,
#  19,
#  35,
#  10,
#  30,
#  4778,
#  2,
#  94,
#  25,
#  49,
#  29,
#  5212,
#  4,
#  3,
#  22,
#  8,
#  16,
#  4,
#  0,
#  5348,
#  1,
#  0,
#  150,
#  854,
#  467,
#  12297,
#  334,
#  30,
#  17194,
#  2434,
#  200,
#  1293,
#  141,
#  12297,
#  215,
#  37,
#  89,
#  0,
#  247,
#  5233,
#  55,
#  116,
#  7088,
#  38,
#  1206,
#  32,
#  197,
#  11,
#  0,
#  45,
#  181,
#  4778,
#  529,
#  2,
#  12297,
#  11,
#  0,
#  1834,
#  1,
#  1912,
#  5233,
#  41,
#  34,
#  32,
#  228,
#  75,
#  4778,
#  435,
#  733,
#  2399,
#  2,
#  0,
#  194,
#  17,
#  86,
#  1073,
#  11,
#  30,
#  14022,
#  30107,
#  18,
#  0,
#  12061,
#  58114,
#  34,
#  50,
#  2419,
#  616,
#  4,
#  0,
#  150,
#  854,
#  0,
#  45,
#  567,
#  8716,
#  4778,
#  2935,
#  1033,
#  14497,
#  26,
#  10,
#  636,
#  359,
#  19,
#  26,
#  5385,
#  154,
#  191,
#  2935,
#  1033,
#  14497,
#  334,
#  153,
#  10,
#  917,
#  4,
#  3,
#  12,
#  20,
#  7,
#  19,
#  0,
#  194,
#  4778,
#  17,
#  989,
#  11,
#  5,
#  567,
#  1606,
#  26,
#  10,
#  13,
#  32,
#  890,
#  19,
#  47,
#  848,
#  14497,
#  11,
#  0,
#  1834,
#  1,
#  173,
#  4778,
#  208,
#  4,
#  153,
#  10,
#  917,
#  14497,
#  5463,
#  23,
#  0,
#  419,
#  12953,
#  917,
#  10,
#  6878,
#  4,
#  32,
#  139,
#  35,
#  1346,
#  0,
#  2878,
#  1,
#  15068,
#  917,
#  154,
#  99,
#  3465,
#  38,
#  652,
#  445,
#  6,
#  89,
#  2,
#  3133,
#  43,
#  917,
#  11,
#  46,
#  3591,
#  54,
#  11,
#  15347,
#  1555,
#  13,
#  2965,
#  4,
#  44,
#  258,
#  14497,
#  1164,
#  153,
#  35,
#  88,
#  3221,
#  1131,
#  52,
#  38,
#  751,
#  445,
#  6,
#  89,
#  1049,
#  522,
#  2,
#  1791,
#  4,
#  5805,
#  23,
#  1556,
#  1,
#  5128,
#  2,
#  1293,
#  14497,
#  14,
#  2654,
#  1,
#  11064,
#  33,
#  35,
#  88,
#  29372,
#  966,
#  30,
#  1334,
#  518,
#  99,
#  1131,
#  2,
#  308,
#  159,
#  512,
#  0,
#  805,
#  1,
#  43,
#  1258,
#  218,
#  1258,
#  1037,
#  33,
#  1391,
#  0,
#  908,
#  1,
#  741,
#  64,
#  966,
#  4,
#  442,
#  32,
#  73,
#  2913,
#  19,
#  75,
#  3,
#  73,
#  2965,
#  27,
#  0,
#  1258,
#  1,
#  275,
#  1555,
#  159,
#  4319,
#  2518,
#  498,
#  4,
#  727,
#  10638,
#  18741,
#  30,
#  762,
#  246,
#  986,
#  73,
#  31,
#  177,
#  97,
#  6,
#  740,
#  3272,
#  23,
#  912,
#  6,
#  0,
#  362,
#  1,
#  442,
#  14497,
#  14,
#  948,
#  39,
#  2025,
#  222,
#  150,
#  741,
#  476,
#  1818,
#  2,
#  29,
#  2985,
#  39,
#  1021,
#  4,
#  0,
#  854,
#  1,
#  3,
#  12,
#  20,
#  12,
#  4,
#  302,
#  14497,
#  14,
#  602,
#  1,
#  917,
#  10,
#  647,
#  26,
#  17,
#  347,
#  4,
#  5,
#  112,
#  1,
#  311,
#  79,
#  29,
#  3567,
#  2,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  47,
#  1,
#  29,
#  948,
#  13,
#  50,
#  2158,
#  1589,
#  67,
#  621,
#  2749,
#  26185,
#  14,
#  15643,
#  4,
#  29,
#  0,
#  10464,
#  2,
#  44,
#  199,
#  26185,
#  1460,
#  19,
#  51,
#  636,
#  1045,
#  344,
#  1774,
#  133,
#  0,
#  2581,
#  1,
#  93,
#  917,
#  11,
#  5,
#  244,
#  389,
#  445,
#  4,
#  152,
#  2,
#  0,
#  147,
#  2581,
#  1,
#  371,
#  39,
#  4579,
#  20847,
#  28,
#  9216,
#  4,
#  0,
#  940,
#  1974,
#  1,
#  371,
#  19,
#  0,
#  1131,
#  25,
#  44,
#  1728,
#  35,
#  5213,
#  15643,
#  2,
#  5,
#  143,
#  1,
#  4,
#  33,
#  1131,
#  73,
#  9711,
#  4,
#  5825,
#  1,
#  50095,
#  66,
#  61,
#  26,
#  17,
#  4,
#  43,
#  567,
#  762,
#  6,
#  175,
#  94,
#  13,
#  118,
#  917,
#  684,
#  1145,
#  78,
#  123,
#  507,
#  13042,
#  5567,
#  310,
#  6,
#  369,
#  6,
#  4106,
#  0,
#  1797,
#  6,
#  118,
#  5464,
#  917,
#  2,
#  153,
#  71,
#  38,
#  4,
#  608,
#  183,
#  19,
#  10,
#  608,
#  199,
#  94,
#  184,
#  11,
#  71,
#  6187,
#  9033,
#  11,
#  7183,
#  71,
#  1225,
#  0,
#  33800,
#  1,
#  0,
#  1797,
#  26185,
#  363,
#  88,
#  391,
#  30,
#  4778,
#  35,
#  1045,
#  66,
#  0,
#  2757,
#  42433,
#  2068,
#  29,
#  948,
#  39,
#  2025,
#  24,
#  55,
#  9929,
#  7088,
#  141,
#  4186,
#  1,
#  29,
#  501,
#  25,
#  3235,
#  63,
#  10270,
#  5233,
#  3244,
#  9606,
#  4,
#  3,
#  ...]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

Counter(words)['the']
# Out:
# 1061396

# %%
import random

random.random()
# Out:
# 0.21479541558167647

# %%
len(words)
# Out:
# 16680599

# %%
## Your code here
import random
from collections import Counter

# threshold parameter t
t = 1e-5

# go through int_words and discard
# how to get frequency?

freq_dict = Counter(words)
total_counts = len(words)
for k,v in freq_dict.items():
    freq_dict[k] = v/total_counts

train_words = [word for word in words if random.random() > (1-np.sqrt(t/freq_dict[word]))]

# %%
len(train_words)
# Out:
# 4626307

# %%
train_words = [vocab_to_int[word] for word in train_words]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1,window_size+1)
    start = idx-R if idx-R > 0 else 0
    end = idx+R+1 if idx+R+1 < len(words) else len(words)-1
    target = list(set(words[start:idx] + words[idx+1:end]))
    
    return target

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32,shape=[None])
    labels = tf.placeholder(dtype=tf.int32,shape=[None,None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=[n_vocab,n_embedding],minval=-1,maxval=1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(params=embedding,ids=inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=[n_vocab,n_embedding],stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b,\
                                      labels=labels,inputs=embed,\
                                      num_sampled=n_sampled,num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.8505 0.4736 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 17.6414 0.4364 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 17.3847 0.3975 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.3878 0.3972 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.2314 0.3951 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.1116 0.3969 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 17.0263 0.3998 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 16.9067 0.3955 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 16.7016 0.3944 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 16.6516 0.4074 sec/batch
# Nearest to had: suspicion, alexanderplatz, nas, coosa, duh, resettlement, larsen, vilification,
# Nearest to his: joris, herrick, surfer, moravians, ferns, shan, mihrab, rectus,
# Nearest to most: warrant, scrooge, questionable, gist, austro, varsity, intuitive, race,
# Nearest to they: diuretic, scooters, mussorgsky, settler, bloom, registrar, qualitative, auburn,
# Nearest to war: harassed, hindi, hitchhikers, thatcherism, markkaa, petrovich, unesco, connecting,
# Nearest to to: bulldozer, rdenas, droves, sig, halle, suzerain, alhonen, iguanodon,
# Nearest to can: tabby, shakyamuni, lichens, sol, parables, superintendence, metabolite, glock,
# Nearest to states: ratiocinator, asians, glastonbury, dialogs, tp, nsdap, falange, evas,
# Nearest to joseph: cyclical, colson, malta, health, partly, depredations, madge, behaved,
# Nearest to professional: sentiments, sarandon, bogart, doesburg, moriah, neotropical, philippians, shechem,
# Nearest to scale: unicast, congress, knocking, applescript, expressionism, bro, ghibli, duchesse,
# Nearest to mean: visconti, roped, skilling, margins, llewellyn, protege, rectangles, rossellini,
# Nearest to account: rejuvenated, mouse, calixtus, discs, papiamento, jiangsu, forerunners, reschedule,
# Nearest to mainly: transnational, musaf, makeup, descendants, centralize, snp, grandparents, magi,
# Nearest to san: deist, supplying, hostage, crystallized, command, beaconsfield, bessarabia, mag,
# Nearest to discovered: universite, labyrinth, radish, mantra, firaxis, sterreich, ghaznavid, mons,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.6484 0.4010 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.3700 0.3953 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.2871 0.3931 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.1817 0.3956 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 16.0030 0.3945 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 15.9402 0.4021 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.8375 0.3937 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.7971 0.3926 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.6113 0.3931 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.5193 0.3996 sec/batch
# Nearest to had: alexanderplatz, suspicion, nas, coosa, resettlement, larsen, carcassi, duh,
# Nearest to his: joris, herrick, surfer, ferns, moravians, shan, gallus, foresight,
# Nearest to most: gist, varsity, scrooge, questionable, warrant, austro, waveforms, race,
# Nearest to they: mussorgsky, scooters, settler, diuretic, bloom, qualitative, newbery, democratization,
# Nearest to war: harassed, hindi, hitchhikers, markkaa, thatcherism, petrovich, unesco, haploid,
# Nearest to to: bulldozer, rdenas, droves, sig, mand, sedimentation, veeck, suzerain,
# Nearest to can: tabby, shakyamuni, lichens, sol, parables, sexual, superintendence, wagon,
# Nearest to states: ratiocinator, asians, dialogs, glastonbury, tp, falange, nsdap, mantis,
# Nearest to joseph: cyclical, malta, colson, health, partly, madge, depredations, behaved,
# Nearest to professional: sentiments, bogart, sarandon, philippians, doesburg, moriah, neotropical, shechem,
# Nearest to scale: unicast, congress, knocking, applescript, expressionism, bro, ghibli, qattara,
# Nearest to mean: visconti, roped, skilling, margins, llewellyn, protege, rectangles, rossellini,
# Nearest to account: rejuvenated, mouse, discs, reschedule, calixtus, papiamento, jiangsu, forerunners,
# Nearest to mainly: makeup, musaf, transnational, descendants, centralize, snp, popolare, grandparents,
# Nearest to san: deist, supplying, hostage, command, qinghai, crystallized, mag, bessarabia,
# Nearest to discovered: universite, labyrinth, radish, mons, firaxis, ghaznavid, sterreich, mantra,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.4218 0.4018 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.3076 0.3958 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 15.2674 0.3926 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 15.0917 0.3944 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 14.9909 0.3938 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.8862 0.3932 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.8024 0.3941 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.7119 0.3916 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.6342 0.3948 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 14.5238 0.3982 sec/batch
# Nearest to had: alexanderplatz, suspicion, nas, coosa, resettlement, duh, larsen, carcassi,
# Nearest to his: joris, herrick, ferns, foresight, surfer, moravians, shan, rectus,
# Nearest to most: intuitive, scrooge, austro, gist, varsity, warrant, brp, tempos,
# Nearest to they: bloom, scooters, mussorgsky, settler, newbery, diuretic, democratization, auburn,
# Nearest to war: harassed, hindi, hitchhikers, markkaa, thatcherism, connecting, aromatics, unesco,
# Nearest to to: sig, bulldozer, droves, mun, mand, suzerain, cubism, veeck,
# Nearest to can: lichens, tabby, sol, shakyamuni, sexual, parables, wagon, bowling,
# Nearest to states: asians, ratiocinator, glastonbury, dialogs, tp, falange, nsdap, peckinpah,
# Nearest to joseph: cyclical, malta, health, colson, partly, depredations, madge, captained,
# Nearest to professional: sentiments, sarandon, bogart, philippians, doesburg, moriah, neotropical, shechem,
# Nearest to scale: unicast, congress, knocking, applescript, expressionism, ghibli, tone, duchesse,
# Nearest to mean: visconti, roped, skilling, margins, ravaging, llewellyn, rectangles, propraetor,
# Nearest to account: rejuvenated, mouse, reschedule, discs, papiamento, calixtus, jiangsu, forerunners,
# Nearest to mainly: makeup, musaf, transnational, descendants, centralize, snp, prost, magi,
# Nearest to san: supplying, deist, hostage, crystallized, mag, command, qinghai, bretons,
# Nearest to discovered: universite, labyrinth, radish, mons, ghaznavid, firaxis, sterreich, embarking,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 14.4837 0.4010 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 14.3941 0.3952 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 14.1275 0.3952 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 14.1286 0.3922 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 14.0579 0.3955 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 13.9704 0.3978 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.8826 0.3982 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 13.8125 0.3926 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 13.7308 0.5033 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 13.6577 0.5273 sec/batch
# Nearest to had: suspicion, alexanderplatz, resettlement, nas, carcassi, coosa, duh, larsen,
# Nearest to his: joris, ferns, herrick, foresight, shan, surfer, van, buch,
# Nearest to most: intuitive, scrooge, brp, austro, trixie, gist, indian, scavenging,
# Nearest to they: bloom, settler, mussorgsky, newbery, democratization, estep, scooters, diuretic,
# Nearest to war: harassed, hindi, hitchhikers, markkaa, the, aromatics, haploid, rhyming,
# Nearest to to: droves, mand, adoration, mun, sig, bulldozer, grazing, suzerain,
# Nearest to can: parables, sexual, lichens, tabby, wagon, sol, kp, shakyamuni,
# Nearest to states: asians, ratiocinator, dialogs, glastonbury, tp, peckinpah, nsdap, vile,
# Nearest to joseph: malta, colson, cyclical, health, veritas, madge, partly, depredations,
# Nearest to professional: sentiments, bogart, sarandon, doesburg, philippians, moriah, shechem, neotropical,
# Nearest to scale: unicast, congress, knocking, applescript, expressionism, tone, ghibli, bro,
# Nearest to mean: visconti, skilling, roped, margins, ravaging, rectangles, propraetor, monkeys,
# Nearest to account: rejuvenated, mouse, reschedule, discs, stool, copernicanism, papiamento, calixtus,
# Nearest to mainly: makeup, descendants, musaf, transnational, snp, tributes, centralize, magi,
# Nearest to san: supplying, hostage, deist, crystallized, command, qinghai, mag, declension,
# Nearest to discovered: universite, radish, labyrinth, mons, ghaznavid, mantra, firaxis, sheave,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 13.6079 0.4933 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 13.4761 0.6324 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 13.3595 0.5949 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 13.3012 0.5372 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 13.2151 0.5052 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 13.1639 0.4914 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 13.0964 0.3690 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 12.9832 0.4425 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 12.8136 0.4273 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 12.6962 0.5193 sec/batch
# Nearest to had: suspicion, alexanderplatz, resettlement, larsen, carcassi, nas, mano, downright,
# Nearest to his: herrick, ferns, arch, shan, joris, foresight, moravians, surfer,
# Nearest to most: questionable, austro, trixie, frog, intuitive, gist, tragic, brp,
# Nearest to they: bloom, settler, mussorgsky, scooters, diuretic, democratization, newbery, qualitative,
# Nearest to war: harassed, hitchhikers, hindi, aromatics, markkaa, haploid, eponym, petrovich,
# Nearest to to: the, of, in, droves, and, a, planing, tarawa,
# Nearest to can: sexual, tabby, wagon, parables, kp, lichens, sol, dashboard,
# Nearest to states: asians, ratiocinator, dialogs, glastonbury, peckinpah, tp, falange, theologian,
# Nearest to joseph: malta, colson, cyclical, health, veritas, depredations, behaved, engelm,
# Nearest to professional: bogart, sarandon, sentiments, doesburg, shechem, philippians, neotropical, moriah,
# Nearest to scale: unicast, congress, knocking, expressionism, applescript, tone, finch, pizarro,
# Nearest to mean: visconti, skilling, roped, margins, ravaging, llewellyn, propraetor, minot,
# Nearest to account: rejuvenated, mouse, reschedule, discs, calixtus, papiamento, stool, copernicanism,
# Nearest to mainly: makeup, descendants, musaf, transnational, magi, averages, snp, drafts,
# Nearest to san: supplying, hostage, deist, crystallized, declension, endpin, bessarabia, qinghai,
# Nearest to discovered: universite, radish, mons, labyrinth, sterreich, firaxis, ghaznavid, sheave,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 12.7172 0.4068 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 12.6216 0.3924 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 12.5046 0.4485 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 12.4227 0.5046 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 12.3446 0.5346 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 12.2727 0.4562 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 12.1696 0.4916 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 12.0447 0.4376 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 12.0205 0.4141 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 12.0581 0.4053 sec/batch
# Nearest to had: suspicion, alexanderplatz, larsen, nas, resettlement, fuzes, elaborated, igm,
# Nearest to his: ferns, herrick, is, a, in, arch, of, foresight,
# Nearest to most: questionable, trixie, ignaz, boing, intuitive, larkin, brp, frog,
# Nearest to they: of, that, settler, democratization, bloom, qualitative, mussorgsky, inhibitor,
# Nearest to war: harassed, hitchhikers, hindi, markkaa, aromatics, haploid, xith, paula,
# Nearest to to: the, in, and, of, a, is, on, zero,
# Nearest to can: wagon, parables, sister, srebrenica, kp, sexual, hydrostatics, dashboard,
# Nearest to states: asians, peckinpah, ratiocinator, glastonbury, dialogs, tp, ratified, theologian,
# Nearest to joseph: malta, cyclical, colson, health, depredations, behaved, veritas, engelm,
# Nearest to professional: sarandon, sentiments, shechem, bogart, doesburg, cinemas, philippians, injuries,
# Nearest to scale: unicast, congress, knocking, expressionism, tone, applescript, finch, theoria,
# Nearest to mean: visconti, skilling, roped, margins, ravaging, llewellyn, minot, monkeys,
# Nearest to account: rejuvenated, mouse, reschedule, discs, papiamento, stool, xi, invariable,
# Nearest to mainly: descendants, transnational, musaf, makeup, magi, drafts, snp, cuvier,
# Nearest to san: hostage, supplying, deist, crystallized, masse, declension, friesland, bretons,
# Nearest to discovered: universite, mons, radish, labyrinth, sheave, mantra, secured, ghaznavid,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 11.9183 0.4750 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 11.8667 0.4368 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 11.7904 0.4407 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 11.6560 0.4987 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 11.7301 0.4781 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 11.5798 0.4505 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 11.4026 0.4651 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 11.4380 0.4431 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 11.3649 0.5225 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 11.3633 0.4428 sec/batch
# Nearest to had: are, without, has, was, to, the, downright, suspicion,
# Nearest to his: as, is, a, in, an, on, s, was,
# Nearest to most: from, of, for, that, is, which, ignaz, martov,
# Nearest to they: a, for, is, the, to, and, that, s,
# Nearest to war: new, hindi, harassed, hitchhikers, aromatics, xith, markkaa, eponym,
# Nearest to to: the, that, of, a, and, in, is, as,
# Nearest to can: an, as, that, for, which, a, is, by,
# Nearest to states: peckinpah, asians, glastonbury, dialogs, ratiocinator, reclamation, tight, on,
# Nearest to joseph: malta, cyclical, colson, health, depredations, behaved, veritas, engelm,
# Nearest to professional: sarandon, sentiments, shechem, doesburg, bogart, moriah, injuries, philippians,
# Nearest to scale: unicast, congress, knocking, applescript, tone, finch, theoria, da,
# Nearest to mean: visconti, skilling, roped, margins, ravaging, monkeys, minot, summed,
# Nearest to account: mouse, rejuvenated, reschedule, discs, xi, papiamento, stool, jiangsu,
# Nearest to mainly: descendants, musaf, makeup, transnational, cuvier, magi, tributes, snp,
# Nearest to san: deist, hostage, supplying, masse, crystallized, friesland, declension, msp,
# Nearest to discovered: universite, radish, mons, sheave, labyrinth, ghaznavid, mantra, sterreich,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 11.3385 0.4167 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 11.1885 0.4649 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 10.9977 0.4044 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 11.0455 0.4057 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 10.9565 0.4090 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 10.8443 0.4297 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 10.8728 0.4053 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 10.8577 0.4274 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 10.6632 0.4374 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 10.6155 0.4600 sec/batch
# Nearest to had: of, which, not, the, that, was, from, and,
# Nearest to his: as, was, the, at, by, more, to, but,
# Nearest to most: the, from, of, and, to, has, have, s,
# Nearest to they: to, the, not, of, and, an, that, as,
# Nearest to war: were, been, the, s, new, to, which, this,
# Nearest to to: of, as, the, it, on, a, and, that,
# Nearest to can: that, as, be, is, used, for, it, s,
# Nearest to states: its, as, for, or, it, not, the, also,
# Nearest to joseph: malta, cyclical, colson, depredations, health, veritas, intensive, zweites,
# Nearest to professional: sarandon, shechem, injuries, sentiments, philippians, doesburg, moriah, bogart,
# Nearest to scale: unicast, tone, knocking, congress, religiously, have, applescript, expressionism,
# Nearest to mean: visconti, skilling, roped, minot, monkeys, ravaging, flattery, fuller,
# Nearest to account: mouse, rejuvenated, reschedule, discs, ems, xi, stool, homographs,
# Nearest to mainly: descendants, musaf, cuvier, drafts, kato, targums, transnational, scarface,
# Nearest to san: hostage, deist, masse, crystallized, supplying, retold, friesland, mag,
# Nearest to discovered: mons, radish, universite, sheave, ghaznavid, labyrinth, christopher, mantra,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 10.5014 0.4628 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 10.6651 0.4976 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 10.5082 0.4532 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 10.5016 0.4554 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 10.4721 0.4339 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 10.2949 0.4496 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 10.3533 0.4386 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 10.2813 0.4758 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 10.1080 0.4565 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 10.1457 0.4508 sec/batch
# Nearest to had: was, the, in, of, he, there, a, not,
# Nearest to his: he, was, the, from, of, on, it, after,
# Nearest to most: and, the, has, in, of, have, more, to,
# Nearest to they: but, and, a, the, some, of, to, that,
# Nearest to war: were, was, the, who, including, he, since, eight,
# Nearest to to: in, the, and, of, a, not, with, on,
# Nearest to can: be, is, this, that, used, a, are, in,
# Nearest to states: to, with, in, from, by, and, since, on,
# Nearest to joseph: malta, depredations, health, colson, cyclical, veritas, tenses, behaved,
# Nearest to professional: shechem, injuries, sarandon, sentiments, philippians, moriah, cinemas, bogart,
# Nearest to scale: unicast, knocking, tone, leap, expressionism, applescript, religiously, congress,
# Nearest to mean: roped, visconti, minot, flattery, skilling, interpretations, ravaging, altenburg,
# Nearest to account: mouse, reschedule, discs, rejuvenated, shire, equilibrium, stool, counterparts,
# Nearest to mainly: descendants, cuvier, musaf, kato, drafts, meaning, shiraz, popolare,
# Nearest to san: hostage, deist, friesland, crystallized, ansel, command, retold, msp,
# Nearest to discovered: universite, christopher, radish, mons, sheave, ghaznavid, vijay, reiterated,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 10.1034 0.4239 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 10.0179 0.4319 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 9.9414 0.2242 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 9.9125 0.4027 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 9.7724 0.4036 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 9.7650 0.4302 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 9.6946 0.4500 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 9.6889 0.4127 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 9.5559 0.4102 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 9.4618 0.4454 sec/batch
# Nearest to had: his, was, in, the, of, at, and, to,
# Nearest to his: had, he, was, who, the, to, s, in,
# Nearest to most: to, that, the, of, a, there, in, is,
# Nearest to they: to, is, the, their, not, that, have, an,
# Nearest to war: the, of, states, were, had, in, s, after,
# Nearest to to: the, of, in, is, a, that, this, an,
# Nearest to can: such, a, is, if, or, to, the, not,
# Nearest to states: in, the, united, has, is, and, of, for,
# Nearest to joseph: malta, health, depredations, cyclical, colson, veritas, intensive, sixteen,
# Nearest to professional: shechem, injuries, sarandon, philippians, moriah, cinemas, sentiments, per,
# Nearest to scale: unicast, there, ghibli, tone, knocking, applescript, congress, it,
# Nearest to mean: roped, minot, visconti, flattery, summed, fuller, skilling, interpretations,
# Nearest to account: discs, shire, two, rejuvenated, mouse, counterparts, reschedule, xi,
# Nearest to mainly: descendants, musaf, cuvier, meaning, drafts, modern, death, lisle,
# Nearest to san: hostage, msp, command, deist, friesland, ansel, longer, crystallized,
# Nearest to discovered: universite, story, mons, highest, slocum, vijay, todt, ghaznavid,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 9.4963 0.4142 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 9.4850 0.4098 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 9.3087 0.4445 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 9.1287 0.4593 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 9.1400 0.4078 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 9.2556 0.5003 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 9.3784 0.5014 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 9.1470 0.4678 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 9.0036 0.4669 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 9.0506 0.4870 sec/batch
# Nearest to had: the, of, on, to, he, after, in, was,
# Nearest to his: he, was, in, on, the, after, to, of,
# Nearest to most: the, of, and, that, in, with, a, this,
# Nearest to they: to, in, of, the, all, and, not, it,
# Nearest to war: was, during, the, states, had, in, were, under,
# Nearest to to: the, of, in, and, that, by, they, a,
# Nearest to can: is, that, be, these, or, a, as, not,
# Nearest to states: since, united, in, of, and, with, to, under,
# Nearest to joseph: malta, health, depredations, order, cyclical, colson, veritas, sixteen,
# Nearest to professional: injuries, shechem, cinemas, per, sarandon, moriah, philippians, sentiments,
# Nearest to scale: than, about, since, are, which, often, for, a,
# Nearest to mean: flattery, roped, minot, summed, visconti, fuller, shall, interpretations,
# Nearest to account: considered, probably, buildings, expressed, american, discs, generally, counterparts,
# Nearest to mainly: called, often, descendants, death, five, meaning, zero, seven,
# Nearest to san: command, hostage, origin, emotive, friesland, masse, ansel, retold,
# Nearest to discovered: story, prime, terms, rumors, against, allowed, commonly, e,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 9.1320 0.4705 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 9.0059 0.4611 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 8.7679 0.4536 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 8.7973 0.4148 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 8.8573 0.4635 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 8.7206 0.5190 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 8.7142 0.5616 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 8.9144 0.4925 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 8.4252 0.4084 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 8.6305 0.4073 sec/batch
# Nearest to had: of, the, to, on, they, after, in, s,
# Nearest to his: he, was, in, of, to, it, and, had,
# Nearest to most: to, in, a, with, on, of, the, and,
# Nearest to they: to, that, of, the, for, their, however, a,
# Nearest to war: to, in, the, after, was, and, however, of,
# Nearest to to: the, and, of, in, a, it, that, with,
# Nearest to can: is, or, be, that, an, such, a, are,
# Nearest to states: the, and, in, united, of, s, on, to,
# Nearest to joseph: malta, health, depredations, said, want, cyclical, sixteen, irradiated,
# Nearest to professional: injuries, shechem, moriah, mandate, cinemas, consequences, sarandon, occasionally,
# Nearest to scale: generally, each, too, thus, point, than, number, certain,
# Nearest to mean: flattery, shall, summed, minot, scholars, shortages, andree, scalpel,
# Nearest to account: often, considered, basis, t, language, been, least, as,
# Nearest to mainly: its, been, three, on, are, most, often, meaning,
# Nearest to san: hostage, meaning, emotive, retold, command, longer, up, scientific,
# Nearest to discovered: present, story, during, when, e, i, notable, commonly,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 8.6310 0.4175 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 8.4293 0.4093 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 8.4884 0.4166 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 8.5239 0.4055 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 8.2842 0.4031 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 8.2969 0.4086 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 8.2742 0.4144 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 8.3923 0.4175 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 8.3169 0.4101 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 8.2256 0.4161 sec/batch
# Nearest to had: the, been, of, was, to, in, and, from,
# Nearest to his: he, in, was, had, and, the, of, at,
# Nearest to most: the, to, they, and, more, of, its, as,
# Nearest to they: that, not, the, some, but, as, to, a,
# Nearest to war: was, against, states, during, of, government, the, in,
# Nearest to to: the, in, and, of, but, was, that, as,
# Nearest to can: be, or, are, if, is, use, not, that,
# Nearest to states: united, of, in, the, had, and, on, to,
# Nearest to joseph: one, john, nine, seven, came, best, three, york,
# Nearest to professional: best, success, injuries, formed, started, yet, career, mandate,
# Nearest to scale: have, be, such, number, less, than, generally, too,
# Nearest to mean: referred, kind, shortages, shall, organisations, interpretations, billion, flattery,
# Nearest to account: man, to, they, that, some, before, as, the,
# Nearest to mainly: they, are, been, modern, new, a, and, the,
# Nearest to san: science, hostage, meaning, summer, down, scientific, up, emotive,
# Nearest to discovered: may, would, is, see, order, similar, field, time,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 8.4211 0.4315 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 7.9811 0.4502 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 8.2942 0.4078 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 8.1533 0.4578 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 7.8891 0.4369 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 8.0885 0.4904 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.0185 0.4477 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.0180 0.4116 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 7.9876 0.1132 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 7.8998 0.4404 sec/batch
# Nearest to had: in, to, the, been, he, who, was, of,
# Nearest to his: was, he, in, did, him, had, new, and,
# Nearest to most: the, and, of, in, with, as, to, is,
# Nearest to they: to, as, a, in, the, not, that, of,
# Nearest to war: national, government, states, was, during, army, united, until,
# Nearest to to: as, and, in, not, for, that, the, this,
# Nearest to can: be, this, is, or, that, not, a, using,
# Nearest to states: united, the, national, government, war, was, state, and,
# Nearest to joseph: john, one, wrote, nine, seven, american, english, th,
# Nearest to professional: success, best, made, popular, hold, career, s, first,
# Nearest to scale: such, making, other, which, with, large, a, various,
# Nearest to mean: things, rather, used, being, is, either, instead, sometimes,
# Nearest to account: been, of, influence, they, the, an, in, but,
# Nearest to mainly: of, in, the, from, and, over, is, a,
# Nearest to san: summer, create, scientific, especially, again, largely, recent, november,
# Nearest to discovered: which, as, a, same, with, given, first, name,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 7.8587 0.4346 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 7.9305 0.4644 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 7.7685 0.4114 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 7.8800 0.4315 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 7.6465 0.4704 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 7.5969 0.4263 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 7.6716 0.4068 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 7.6462 0.4050 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 7.5782 0.4054 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 7.2592 0.4541 sec/batch
# Nearest to had: his, the, were, was, and, of, he, on,
# Nearest to his: he, had, was, who, were, great, the, at,
# Nearest to most: and, the, has, a, to, of, with, many,
# Nearest to they: to, the, and, that, by, this, not, as,
# Nearest to war: states, was, state, government, union, former, united, were,
# Nearest to to: the, and, of, but, a, as, however, an,
# Nearest to can: is, if, such, are, example, be, same, or,
# Nearest to states: united, and, the, in, under, to, state, british,
# Nearest to joseph: john, eight, three, born, six, he, one, american,
# Nearest to professional: years, first, success, s, nine, one, best, eight,
# Nearest to scale: each, with, to, because, such, and, other, possible,
# Nearest to mean: called, things, out, there, is, for, both, cannot,
# Nearest to account: been, were, own, there, the, having, just, by,
# Nearest to mainly: and, to, into, most, were, many, an, for,
# Nearest to san: zero, area, areas, three, major, native, throughout, november,
# Nearest to discovered: but, would, formed, order, important, not, as, a,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 7.4018 0.4741 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 7.4157 0.4269 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 7.5456 0.4092 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 7.5255 0.4027 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 7.3085 0.4446 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 7.3496 0.4597 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 7.4251 0.5717 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 7.3949 0.4652 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.1541 0.5011 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 7.2399 0.4797 sec/batch
# Nearest to had: were, was, after, on, with, from, in, by,
# Nearest to his: he, was, in, himself, by, s, life, of,
# Nearest to most: and, of, some, to, it, as, from, a,
# Nearest to they: to, of, their, as, the, however, have, in,
# Nearest to war: was, were, after, states, army, had, state, took,
# Nearest to to: the, and, of, for, as, in, with, a,
# Nearest to can: used, is, be, that, different, if, which, particular,
# Nearest to states: united, over, state, was, under, established, government, war,
# Nearest to joseph: american, john, one, d, george, born, eight, b,
# Nearest to professional: success, record, career, s, best, by, world, in,
# Nearest to scale: each, can, not, such, an, may, a, that,
# Nearest to mean: given, if, not, any, therefore, find, so, get,
# Nearest to account: the, of, there, with, that, been, have, by,
# Nearest to mainly: also, of, this, its, have, to, that, many,
# Nearest to san: began, three, s, november, up, u, national, california,
# Nearest to discovered: and, but, the, order, little, not, been, that,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 7.2698 0.4787 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.1365 0.4227 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.1572 0.5159 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 7.3069 0.4381 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.0509 0.4392 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 7.0716 0.4745 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 7.2113 0.4170 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 6.9700 0.4463 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.0225 0.4763 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.0408 0.4160 sec/batch
# Nearest to had: and, the, of, in, was, who, became, were,
# Nearest to his: he, was, who, had, after, by, the, s,
# Nearest to most: and, of, the, for, as, a, from, to,
# Nearest to they: it, as, however, the, to, many, not, be,
# Nearest to war: during, was, united, took, states, forces, troops, army,
# Nearest to to: as, the, of, with, and, a, in, from,
# Nearest to can: are, be, or, example, used, that, such, form,
# Nearest to states: nations, united, in, the, countries, of, government, and,
# Nearest to joseph: george, eight, seven, nine, three, five, d, one,
# Nearest to professional: success, career, home, team, record, s, studies, end,
# Nearest to scale: such, each, will, a, be, may, or, more,
# Nearest to mean: is, way, can, difference, be, form, if, defined,
# Nearest to account: the, to, of, been, they, from, in, and,
# Nearest to mainly: of, in, its, which, to, for, the, and,
# Nearest to san: eight, began, signed, whom, york, summer, one, worked,
# Nearest to discovered: and, as, see, an, there, but, to, itself,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.0784 0.4288 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 6.7876 0.4094 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 6.7877 0.4984 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 6.9837 0.4739 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 6.9371 0.4617 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 6.8425 0.4012 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 7.1265 0.4143 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 6.6813 0.4076 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 6.9216 0.4757 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 6.9732 0.4976 sec/batch
# Nearest to had: in, was, the, and, until, were, after, of,
# Nearest to his: he, was, him, after, career, received, famous, who,
# Nearest to most: and, the, of, to, on, as, by, many,
# Nearest to they: to, but, as, that, a, the, and, which,
# Nearest to war: army, during, united, troops, established, forces, was, declared,
# Nearest to to: and, the, of, but, as, which, some, it,
# Nearest to can: if, value, be, or, system, uses, form, is,
# Nearest to states: united, the, national, in, government, over, under, europe,
# Nearest to joseph: one, william, eight, seven, george, german, robert, four,
# Nearest to professional: best, career, won, played, play, young, zero, record,
# Nearest to scale: be, is, limited, as, such, more, may, higher,
# Nearest to mean: if, is, be, equivalent, given, higher, difference, may,
# Nearest to account: the, and, some, s, to, of, as, an,
# Nearest to mainly: and, been, with, most, to, in, over, other,
# Nearest to san: california, summer, one, five, year, moved, four, third,
# Nearest to discovered: the, an, s, from, a, second, of, by,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 6.6399 0.4965 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 6.7905 0.4459 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 6.7442 0.4398 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 6.7752 0.4460 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 6.8196 0.4545 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 6.6209 0.4156 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 6.6299 0.4246 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 6.7893 0.4559 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 6.5805 0.4321 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 6.6841 0.4045 sec/batch
# Nearest to had: was, in, the, by, he, to, and, of,
# Nearest to his: he, him, who, had, was, became, by, life,
# Nearest to most: to, a, the, it, with, and, of, this,
# Nearest to they: to, that, the, this, their, not, into, as,
# Nearest to war: troops, army, established, civil, union, forces, states, military,
# Nearest to to: the, as, a, and, this, with, for, of,
# Nearest to can: be, are, such, simple, different, using, used, useful,
# Nearest to states: united, government, the, and, union, established, state, countries,
# Nearest to joseph: eight, one, nine, seven, born, john, william, german,
# Nearest to professional: played, best, team, record, association, winning, play, teams,
# Nearest to scale: these, potential, each, process, be, than, increased, amount,
# Nearest to mean: defined, equivalent, if, values, set, real, function, numbers,
# Nearest to account: been, of, not, to, the, on, and, in,
# Nearest to mainly: the, over, of, today, and, as, been, on,
# Nearest to san: california, york, january, june, four, five, france, university,
# Nearest to discovered: of, in, on, about, at, known, first, most,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 6.5672 0.4370 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 6.4535 0.4424 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 6.5328 0.4454 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 6.4992 0.3968 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 6.5035 0.4240 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 6.2807 0.4243 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.2861 0.4270 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 6.3351 0.4064 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 6.4319 0.4517 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 6.5025 0.4109 sec/batch
# Nearest to had: was, he, on, s, were, in, who, did,
# Nearest to his: he, him, had, was, who, himself, s, her,
# Nearest to most: of, the, for, and, in, a, with, to,
# Nearest to they: to, not, although, the, their, in, that, of,
# Nearest to war: army, united, troops, states, established, civil, declared, were,
# Nearest to to: the, and, which, in, with, a, for, it,
# Nearest to can: is, are, using, simple, used, be, or, if,
# Nearest to states: united, state, war, under, government, former, union, national,
# Nearest to joseph: john, william, historian, german, peter, jr, paul, founder,
# Nearest to professional: s, played, team, one, new, best, in, teams,
# Nearest to scale: amount, than, is, high, such, use, are, potential,
# Nearest to mean: defined, define, equivalent, numbers, is, set, value, g,
# Nearest to account: been, and, in, give, the, on, first, as,
# Nearest to mainly: to, also, which, although, other, in, its, the,
# Nearest to san: california, francisco, washington, one, nine, zero, city, eight,
# Nearest to discovered: on, and, in, discovery, the, s, at, known,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.3351 0.4455 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 6.3399 0.4685 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 6.3787 0.4378 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 6.4758 0.4607 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 6.2588 0.4381 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.1972 0.4177 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.2555 0.4221 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.2850 0.4279 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.1694 0.4526 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 6.3727 0.4004 sec/batch
# Nearest to had: was, he, who, became, after, finally, of, took,
# Nearest to his: he, was, him, death, father, had, wife, her,
# Nearest to most: to, a, the, with, more, and, as, for,
# Nearest to they: their, it, a, to, other, that, have, but,
# Nearest to war: army, troops, was, declared, took, had, battle, established,
# Nearest to to: the, a, it, as, an, on, and, this,
# Nearest to can: example, be, used, use, are, type, is, different,
# Nearest to states: united, national, union, member, nations, civil, america, administration,
# Nearest to joseph: john, william, george, one, charles, german, nine, eight,
# Nearest to professional: team, record, ever, players, association, played, play, teams,
# Nearest to scale: each, range, can, development, than, a, because, other,
# Nearest to mean: defined, is, define, precisely, value, if, definition, exactly,
# Nearest to account: the, many, of, an, have, been, though, those,
# Nearest to mainly: traditionally, most, now, separate, been, vast, between, increasingly,
# Nearest to san: california, francisco, washington, two, november, six, four, seven,
# Nearest to discovered: and, the, however, long, between, as, which, an,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.1443 0.4083 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.0742 0.4358 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.2708 0.4276 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.1806 0.4672 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.1700 0.4204 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.1995 0.4638 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.2434 0.4214 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 5.8823 0.4059 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.0518 0.4735 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 6.0214 0.4183 sec/batch
# Nearest to had: was, in, after, were, of, his, s, at,
# Nearest to his: he, himself, had, him, whom, was, who, her,
# Nearest to most: to, as, the, for, and, in, from, it,
# Nearest to they: to, it, that, but, as, could, for, some,
# Nearest to war: army, troops, civil, military, killed, united, established, treaty,
# Nearest to to: for, as, of, the, it, with, and, but,
# Nearest to can: be, are, or, example, used, allows, using, use,
# Nearest to states: united, national, independent, agreement, former, state, country, nations,
# Nearest to joseph: william, john, george, born, one, writer, charles, robert,
# Nearest to professional: record, team, played, home, club, fame, play, hall,
# Nearest to scale: each, high, which, higher, be, than, more, due,
# Nearest to mean: define, equivalent, defined, precisely, numbers, values, constant, follows,
# Nearest to account: view, most, and, of, see, ideas, as, been,
# Nearest to mainly: the, and, has, in, of, from, been, major,
# Nearest to san: francisco, california, nine, washington, four, one, named, six,
# Nearest to discovered: an, also, only, is, it, but, of, about,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.1139 0.4197 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.0923 0.4145 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.2356 0.5065 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.0769 0.4397 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 5.9815 0.4681 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.1976 0.4083 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 5.9652 0.4061 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 5.9213 0.4056 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 5.9356 0.4420 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.0073 0.4593 sec/batch
# Nearest to had: was, in, who, were, return, his, of, and,
# Nearest to his: he, was, him, whom, who, her, had, return,
# Nearest to most: with, other, as, the, it, to, in, a,
# Nearest to they: as, some, but, the, being, to, because, even,
# Nearest to war: troops, army, during, declared, leadership, united, forces, became,
# Nearest to to: as, with, for, in, some, the, a, it,
# Nearest to can: using, or, example, are, be, useful, used, such,
# Nearest to states: united, state, country, union, government, national, countries, nation,
# Nearest to joseph: william, john, robert, charles, french, thomas, peter, born,
# Nearest to professional: played, football, player, record, winning, first, greatest, hall,
# Nearest to scale: higher, than, levels, more, range, a, depends, quality,
# Nearest to mean: equivalent, if, defined, values, define, is, exactly, arbitrary,
# Nearest to account: about, to, all, the, of, a, s, and,
# Nearest to mainly: most, many, of, its, growing, has, mostly, and,
# Nearest to san: francisco, california, five, four, york, six, nine, one,
# Nearest to discovered: as, in, is, the, from, of, there, this,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.0449 0.4234 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 5.9359 0.3228 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 5.9302 0.4003 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 6.0186 0.4091 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 5.9080 0.4212 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 5.9150 0.4009 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 5.9611 0.3926 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 5.7145 0.3945 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 5.8650 0.4447 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 5.8257 0.4149 sec/batch
# Nearest to had: was, after, he, later, became, at, the, s,
# Nearest to his: he, him, himself, who, had, death, whom, was,
# Nearest to most: with, to, many, it, a, more, much, and,
# Nearest to they: to, their, of, that, and, not, however, this,
# Nearest to war: troops, army, union, germany, forces, invasion, soviet, france,
# Nearest to to: a, the, and, of, in, it, as, from,
# Nearest to can: are, using, requires, than, is, useful, such, examples,
# Nearest to states: united, state, federal, union, congress, government, countries, national,
# Nearest to joseph: john, james, william, robert, peter, french, born, henry,
# Nearest to professional: football, played, players, team, sports, won, teams, s,
# Nearest to scale: can, used, are, usually, using, such, is, natural,
# Nearest to mean: defined, equivalent, define, definition, exactly, arbitrary, values, function,
# Nearest to account: of, by, made, been, and, there, believed, that,
# Nearest to mainly: and, many, of, mostly, has, its, parts, in,
# Nearest to san: francisco, california, york, washington, nine, los, five, six,
# Nearest to discovered: where, discovery, these, which, found, only, a, isolated,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 5.8549 0.4025 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 5.6261 0.4470 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 5.6642 0.4359 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 5.6686 0.4335 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 5.7894 0.4362 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 5.8330 0.4752 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 5.6959 0.5757 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 5.6953 0.4442 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 5.6753 0.4763 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 5.8168 0.5281 sec/batch
# Nearest to had: was, he, after, became, were, his, later, took,
# Nearest to his: he, him, who, she, her, was, father, himself,
# Nearest to most: with, to, it, a, this, of, and, for,
# Nearest to they: to, even, it, that, them, have, more, some,
# Nearest to war: troops, army, wars, britain, against, invasion, forces, states,
# Nearest to to: of, the, it, and, in, a, that, as,
# Nearest to can: is, be, are, may, these, simple, example, using,
# Nearest to states: united, state, government, countries, federal, country, union, war,
# Nearest to joseph: john, james, peter, author, william, writer, robert, smith,
# Nearest to professional: sports, football, record, played, success, major, ever, awarded,
# Nearest to scale: are, very, levels, which, easily, can, such, use,
# Nearest to mean: define, defined, values, equal, represents, sets, exactly, corresponding,
# Nearest to account: of, and, the, life, well, that, in, been,
# Nearest to mainly: many, and, its, traditional, been, people, of, to,
# Nearest to san: francisco, california, city, los, diego, washington, four, eight,
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.6174 0.4819 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.6695 0.4069 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.7167 0.4342 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 4.7755 0.4707 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.6956 0.5710 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.7294 0.5105 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.6849 0.4392 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.8005 0.4553 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.7832 0.4731 sec/batch
# Nearest to had: was, after, his, took, who, soon, he, did,
# Nearest to his: he, who, himself, him, her, wife, father, told,
# Nearest to most: to, and, from, many, of, with, in, have,
# Nearest to they: their, to, have, not, but, them, some, that,
# Nearest to war: forces, troops, army, invasion, during, campaign, allied, wars,
# Nearest to to: the, it, a, have, this, with, they, that,
# Nearest to can: be, example, is, or, usually, may, different, are,
# Nearest to states: united, state, independent, nation, civil, government, union, established,
# Nearest to joseph: theologian, historian, founder, charles, john, painter, william, james,
# Nearest to professional: sports, competition, amateur, association, football, sport, teams, athletic,
# Nearest to scale: scales, relative, roughly, mass, lower, than, intervals, approximately,
# Nearest to mean: defined, is, given, function, exactly, value, difference, follows,
# Nearest to account: of, accounts, according, that, life, this, existence, does,
# Nearest to mainly: historically, largely, mostly, period, various, areas, vast, primarily,
# Nearest to san: diego, francisco, california, jose, angeles, oakland, los, washington,
# Nearest to discovered: discovery, found, isolated, astronomers, observed, known, astronomical, possibly,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.5947 0.4251 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.7178 0.4507 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.7701 0.4366 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.6768 0.4144 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.7730 0.4125 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.6650 0.4357 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.6174 0.4785 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.7083 0.4792 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.6847 0.4952 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.6740 0.4922 sec/batch
# Nearest to had: were, his, who, was, he, after, became, by,
# Nearest to his: he, had, him, himself, who, father, died, did,
# Nearest to most: and, many, various, other, more, as, of, in,
# Nearest to they: their, to, them, have, as, it, more, some,
# Nearest to war: troops, invasion, army, during, civil, forced, armed, attacked,
# Nearest to to: a, and, the, with, it, as, however, an,
# Nearest to can: used, be, such, is, or, allows, example, requires,
# Nearest to states: united, national, state, independent, former, government, republic, countries,
# Nearest to joseph: thomas, john, peter, poet, historian, eight, theologian, charles,
# Nearest to professional: sports, team, career, teams, football, earned, amateur, competition,
# Nearest to scale: scales, relatively, smaller, large, mass, small, range, lower,
# Nearest to mean: exactly, value, defined, we, equal, follows, suppose, example,
# Nearest to account: that, as, this, of, these, some, concerning, the,
# Nearest to mainly: largely, principally, mostly, communities, parts, europe, predominantly, various,
# Nearest to san: diego, francisco, california, angeles, jose, los, oakland, santa,
# Nearest to discovered: discovery, found, known, observed, unknown, isolated, distant, possibly,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.6711 0.4854 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.7003 0.5029 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5677 0.3951 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.6269 0.3948 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.6278 0.3927 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.6635 0.3927 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.7624 0.4061 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.7685 0.3983 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.7208 0.3950 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.6146 0.3982 sec/batch
# Nearest to had: after, was, were, took, until, during, faced, remained,
# Nearest to his: he, him, himself, brother, was, death, who, she,
# Nearest to most: and, other, the, more, some, to, of, today,
# Nearest to they: their, it, to, some, out, with, into, the,
# Nearest to war: invasion, army, during, civil, troops, forces, armed, were,
# Nearest to to: the, and, but, as, by, a, it, of,
# Nearest to can: be, example, or, simple, instance, means, if, different,
# Nearest to states: united, state, former, and, of, republic, national, officially,
# Nearest to joseph: theologian, paul, thomas, smith, john, founder, writer, historian,
# Nearest to professional: career, football, sports, team, hall, played, baseball, players,
# Nearest to scale: higher, lower, than, small, low, range, due, increasing,
# Nearest to mean: value, equivalent, exactly, defined, can, gives, denote, means,
# Nearest to account: this, writings, accounts, idea, that, about, give, historical,
# Nearest to mainly: mostly, other, especially, most, today, predominantly, areas, parts,
# Nearest to san: francisco, diego, california, jose, angeles, mexico, los, oakland,
# Nearest to discovered: discovery, isolated, planet, mass, observed, unknown, decay, earth,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.6896 0.4054 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.6526 0.3894 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.5749 0.3911 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5649 0.3937 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.6357 0.3942 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.6919 0.3938 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.6301 0.2590 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.5748 0.3955 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.6249 0.3907 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.6271 0.3956 sec/batch
# Nearest to had: he, his, was, who, to, him, were, after,
# Nearest to his: he, him, himself, wife, whom, had, brother, father,
# Nearest to most: many, particularly, with, and, other, as, well, in,
# Nearest to they: their, that, to, as, not, have, but, be,
# Nearest to war: army, troops, surrender, civil, invasion, battle, attacked, captured,
# Nearest to to: the, as, a, and, with, in, did, was,
# Nearest to can: types, using, process, possible, such, useful, are, or,
# Nearest to states: united, state, congress, federal, former, national, territory, union,
# Nearest to joseph: john, paul, william, thomas, robert, d, theologian, french,
# Nearest to professional: sports, football, sport, played, soccer, team, best, players,
# Nearest to scale: scales, roughly, equal, instruments, measurements, mass, measured, depends,
# Nearest to mean: defined, equivalent, value, exactly, arithmetic, values, follows, means,
# Nearest to account: as, that, writings, concerning, who, according, of, life,
# Nearest to mainly: parts, historically, communities, predominantly, mostly, largely, primarily, minority,
# Nearest to san: francisco, diego, california, jose, oakland, angeles, los, florida,
# Nearest to discovered: discovery, of, earth, planet, planetary, observed, atmosphere, solar,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.6047 0.3963 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.6567 0.3918 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.5401 0.3934 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.5681 0.3930 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.5622 0.3889 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.6239 0.3914 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.5378 0.3932 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.4033 0.3902 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.4967 0.3909 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.5306 0.3936 sec/batch
# Nearest to had: after, took, was, were, he, did, later, his,
# Nearest to his: he, him, himself, brother, wife, father, her, had,
# Nearest to most: other, many, in, also, and, as, has, more,
# Nearest to they: their, them, to, but, even, have, when, not,
# Nearest to war: army, troops, armed, invasion, forces, campaign, soldiers, surrender,
# Nearest to to: the, as, this, with, but, in, some, a,
# Nearest to can: if, is, be, a, simple, normal, that, or,
# Nearest to states: united, state, congress, federal, countries, u, under, nations,
# Nearest to joseph: john, peter, historian, theologian, smith, james, paul, philosopher,
# Nearest to professional: competition, amateur, sports, sporting, football, sport, tournaments, soccer,
# Nearest to scale: scales, mass, energy, quantities, large, measured, than, decreasing,
# Nearest to mean: defined, is, exactly, number, equivalent, value, equal, follows,
# Nearest to account: accounts, been, of, into, and, they, according, interest,
# Nearest to mainly: mostly, diverse, largely, concentrated, mixed, principally, parts, cultural,
# Nearest to san: california, diego, jose, francisco, oakland, los, angeles, city,
# Nearest to discovered: discovery, observed, earth, abundance, planet, found, dust, cloud,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5669 0.3958 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.5408 0.3930 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5679 0.3915 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.4903 0.3919 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.5827 0.3922 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.6303 0.3898 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.4736 0.3950 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.4946 0.3984 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5729 0.3906 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.4663 0.3944 sec/batch
# Nearest to had: took, after, fell, defeat, forced, he, later, loyal,
# Nearest to his: he, himself, him, wife, her, knew, did, father,
# Nearest to most: many, other, and, from, also, been, with, of,
# Nearest to they: their, to, not, have, them, will, could, but,
# Nearest to war: troops, army, surrender, invasion, civil, armed, wars, attack,
# Nearest to to: a, with, it, this, of, the, an, in,
# Nearest to can: be, example, is, any, are, which, or, usually,
# Nearest to states: united, countries, national, independent, federal, state, nations, administration,
# Nearest to joseph: historian, theologian, john, thomas, founder, peter, james, paul,
# Nearest to professional: amateur, sports, football, association, teams, sport, sporting, competition,
# Nearest to scale: scales, measured, mass, intervals, smaller, relative, quantities, which,
# Nearest to mean: suppose, is, definition, root, defined, we, exactly, does,
# Nearest to account: been, though, that, accepted, with, have, doubt, explain,
# Nearest to mainly: europe, region, predominant, europeans, principally, mostly, displaced, largely,
# Nearest to san: francisco, diego, california, jose, oakland, los, angeles, washington,
# Nearest to discovered: discovery, abundance, isolated, atmosphere, dust, observed, found, discoveries,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5669 0.3968 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5361 0.3889 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.4123 0.3952 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.5223 0.3935 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.6011 0.3942 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.4816 0.3933 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.5067 0.3940 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5579 0.3917 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.4283 0.3925 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.4542 0.3910 sec/batch
# Nearest to had: until, was, after, finally, brought, took, during, were,
# Nearest to his: he, himself, him, father, brother, death, wife, died,
# Nearest to most: and, the, from, it, of, in, with, been,
# Nearest to they: their, to, have, it, but, them, all, the,
# Nearest to war: invasion, army, troops, attacked, allied, armed, killed, fought,
# Nearest to to: for, have, with, of, it, the, and, been,
# Nearest to can: be, allows, used, possible, will, is, or, easier,
# Nearest to states: united, countries, national, state, nations, republic, constitution, government,
# Nearest to joseph: john, historian, peter, smith, william, jr, press, thomas,
# Nearest to professional: amateur, sports, football, teams, club, team, tournaments, prestigious,
# Nearest to scale: scales, resulting, smaller, much, instruments, mass, high, massive,
# Nearest to mean: equivalent, exactly, defined, implies, define, gives, numbers, corresponding,
# Nearest to account: sources, accounts, accepted, being, concerning, writes, knowledge, that,
# Nearest to mainly: region, mostly, predominant, middle, regions, parts, from, almost,
# Nearest to san: francisco, diego, oakland, los, angeles, jose, california, seattle,
# Nearest to discovered: discovery, isolated, discoveries, planet, astronomers, earth, observed, planetary,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.4524 0.3971 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.4706 0.3922 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5230 0.4560 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.5937 0.3918 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.6292 0.3910 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.4046 0.3939 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.5159 0.3879 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.5218 0.3898 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.3696 0.3958 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.4665 0.3936 sec/batch
# Nearest to had: was, were, after, became, until, who, he, soon,
# Nearest to his: he, him, himself, father, friend, whom, brother, wife,
# Nearest to most: and, many, in, the, mainly, has, been, its,
# Nearest to they: to, but, them, would, even, seen, their, so,
# Nearest to war: army, troops, invasion, soviet, forces, civil, allied, armed,
# Nearest to to: be, as, have, which, this, it, a, in,
# Nearest to can: be, will, usually, are, or, such, used, example,
# Nearest to states: united, state, national, countries, member, government, nations, federal,
# Nearest to joseph: historian, paul, writer, smith, thomas, physician, scholar, theologian,
# Nearest to professional: sports, football, hockey, basketball, association, sport, teams, soccer,
# Nearest to scale: scales, materials, depends, range, intervals, slightly, quantities, measured,
# Nearest to mean: is, arithmetic, above, interval, equivalent, value, n, defined,
# Nearest to account: according, reference, sources, concerning, this, identified, details, description,
# Nearest to mainly: mostly, most, and, regions, largely, concentrated, western, among,
# Nearest to san: francisco, diego, jose, california, angeles, santiago, oakland, los,
# Nearest to discovered: discovery, isolated, earth, scattered, atmosphere, planet, possibly, discoveries,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.4785 0.3975 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.4718 0.3940 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /anaconda3/envs/rnn/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# NotFoundError: Key beta2_power_1 not found in checkpoint
# 	 [[Node: save_2/RestoreV2_21 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_2/Const_0, save_2/RestoreV2_21/tensor_names, save_2/RestoreV2_21/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-147-4eeca6a379f0> in <module>()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
# ----> 5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       6     embed_mat = sess.run(embedding)
#
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1437       return
#    1438     sess.run(self.saver_def.restore_op_name,
# -> 1439              {self.saver_def.filename_tensor_name: save_path})
#    1440
#    1441   @staticmethod
#
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: Key beta2_power_1 not found in checkpoint
# 	 [[Node: save_2/RestoreV2_21 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_2/Const_0, save_2/RestoreV2_21/tensor_names, save_2/RestoreV2_21/shape_and_slices)]]
#
# Caused by op 'save_2/RestoreV2_21', defined at:
#   File "/anaconda3/envs/rnn/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/envs/rnn/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-147-4eeca6a379f0>", line 2, in <module>
#     saver = tf.train.Saver()
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1051, in __init__
#     self.build()
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1081, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 402, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 242, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 668, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/anaconda3/envs/rnn/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key beta2_power_1 not found in checkpoint
# 	 [[Node: save_2/RestoreV2_21 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_2/Const_0, save_2/RestoreV2_21/tensor_names, save_2/RestoreV2_21/shape_and_slices)]]

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
